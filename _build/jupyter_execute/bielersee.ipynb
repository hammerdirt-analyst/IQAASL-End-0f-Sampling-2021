# %%
# -*- coding: utf-8 -*-
# This is a report using the data from IQAASL.
# IQAASL was a project funded by the Swiss Confederation
# It produces a summary of litter survey results for a defined region.
# These charts serve as the models for the development of plagespropres.ch
# The data is gathered by volunteers.
# Please remember all copyrights apply, please give credit when applicable
# The repo is maintained by the community effective January 01, 2022
# There is ample opportunity to contribute, learn and teach
# contact dev@hammerdirt.ch

# Dies ist ein Bericht, der die Daten von IQAASL verwendet.
# IQAASL war ein von der Schweizerischen Eidgenossenschaft finanziertes Projekt.
# Es erstellt eine Zusammenfassung der Ergebnisse der Littering-Umfrage für eine bestimmte Region.
# Diese Grafiken dienten als Vorlage für die Entwicklung von plagespropres.ch.
# Die Daten werden von Freiwilligen gesammelt.
# Bitte denken Sie daran, dass alle Copyrights gelten, bitte geben Sie den Namen an, wenn zutreffend.
# Das Repo wird ab dem 01. Januar 2022 von der Community gepflegt.
# Es gibt reichlich Gelegenheit, etwas beizutragen, zu lernen und zu lehren.
# Kontakt dev@hammerdirt.ch

# Il s'agit d'un rapport utilisant les données de IQAASL.
# IQAASL était un projet financé par la Confédération suisse.
# Il produit un résumé des résultats de l'enquête sur les déchets sauvages pour une région définie.
# Ces tableaux ont servi de modèles pour le développement de plagespropres.ch
# Les données sont recueillies par des bénévoles.
# N'oubliez pas que tous les droits d'auteur s'appliquent, veuillez indiquer le crédit lorsque cela est possible.
# Le dépôt est maintenu par la communauté à partir du 1er janvier 2022.
# Il y a de nombreuses possibilités de contribuer, d'apprendre et d'enseigner.
# contact dev@hammerdirt.ch

# sys, file and nav packages:
import datetime as dt
from datetime import date, datetime, time
from babel.dates import format_date, format_datetime, format_time, get_month_names
import locale

# math packages:
import pandas as pd
import numpy as np
from math import pi

# charting:
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker
from matplotlib.ticker import MultipleLocator
import seaborn as sns
from matplotlib import colors as mplcolors

# build report
from reportlab.platypus.flowables import Flowable
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak, ListFlowable, ListItem
from reportlab.lib.pagesizes import A4
from reportlab.rl_config import defaultPageSize
from reportlab.lib.units import inch
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.colors import HexColor
from reportlab.platypus import Table, TableStyle
from reportlab.lib import colors

# the module that has all the methods for handling the data
import resources.featuredata as featuredata

# home brew utitilties
import resources.chart_kwargs as ck
import resources.sr_ut as sut

# images and display
from IPython.display import Markdown as md
from myst_nb import glue

# chart style
sns.set_style("whitegrid")

# colors for gradients
cmap2 = ck.cmap2
colors_palette = ck.colors_palette

# border and row shading for tables
a_color = "saddlebrown"
table_row = "saddlebrown"

# a place to save figures and a 
# method to choose formats
save_fig_prefix = "resources/output/"

# the arguments for formatting the image
save_figure_kwargs = {
    "fname": None,
    "dpi": 300.0,
    "format": "jpeg",
    "bbox_inches": None,
    "pad_inches": 0,
    "bbox_inches": 'tight',
    "facecolor": 'auto',
    "edgecolor": 'auto',
    "backend": None,
}

## !! Begin Note book variables !!

# There are two language variants: german and english
# change both: date_lang and language
date_lang =  'de_DE.utf8'
locale.setlocale(locale.LC_ALL, date_lang)

# the date format of the survey data is defined in the module
date_format = featuredata.date_format

# the language setting use lower case: en or de
# changing the language may require changing the unit label
language = "de"
unit_label = "p/100 m"

# the standard date format is "%Y-%m-%d" if your date column is
# not in this format it will not work.
# these dates cover the duration of the IQAASL project
start_date = "2020-03-01"
end_date ="2021-05-31"
start_end = [start_date, end_date]

# the fail rate used to calculate the most common codes is
# 50% it can be changed:
fail_rate = 50

# Changing these variables produces different reports
# Call the map image for the area of interest
bassin_map = "resources/maps/bielersee_scaled.jpeg"

# the label for the aggregation of all data in the region
top = "Alle Erhebungsgebiete"

# define the feature level and components
# the feature of interest is the Aare (aare) at the river basin (river_bassin) level.
# the label for charting is called 'name'
this_feature = {'slug':'bielersee', 'name':"Bielersee", 'level':'water_name_slug'}

# the lake is in this survey area
this_bassin = "aare"
# label for survey area
bassin_label = "Aare-Erhebungsgebiet"

# these are the smallest aggregated components
# choices are water_name_slug=lake or river, city or location at the scale of a river bassin 
# water body or lake maybe the most appropriate
this_level = 'city'

# identify the lakes of interest for the survey area
lakes_of_interest = ["bielersee"]    


# !! End note book variables !!
## data
# Survey location details (GPS, city, land use)
dfBeaches = pd.read_csv("resources/beaches_with_land_use_rates.csv")
# set the index of the beach data to location slug
dfBeaches.set_index("slug", inplace=True)

# Survey dimensions and weights
dfDims = pd.read_csv("resources/corrected_dims.csv")

# code definitions
dxCodes = pd.read_csv("resources/codes_with_group_names")
dxCodes.set_index("code", inplace=True)

# columns that need to be renamed. Setting the language will automatically
# change column names, code descriptions and chart annotations
columns={"% to agg":"% agg", "% to recreation": "% recreation", "% to woods":"% woods", "% to buildings":"% buildings", "p/100m":"p/100 m"}

# !key word arguments to construct feature data
# !Note the water type allows the selection of river or lakes
# if None then the data is aggregated together. This selection
# is only valid for survey-area reports or other aggregated data
# that may have survey results from both lakes and rivers.
fd_kwargs ={
    "filename": "resources/checked_sdata_eos_2020_21.csv",
    "feature_name": this_feature['slug'], 
    "feature_level": this_feature['level'], 
    "these_features": this_feature['slug'], 
    "component": this_level, 
    "columns": columns, 
    "language": 'de', 
    "unit_label": unit_label, 
    "fail_rate": fail_rate,
    "code_data":dxCodes,
    "date_range": start_end,
    "water_type": None,    
}

fdx = featuredata.Components(**fd_kwargs)

# call the reports and languages
fdx.adjustForLanguage()
fdx.makeFeatureData()
fdx.locationSampleTotals()
fdx.makeDailyTotalSummary()
fdx.materialSummary()
fdx.mostCommon()
fdx.codeGroupSummary()

# !this is the feature data!
fd = fdx.feature_data

# !keyword args to build period data
# the period data is all the data that was collected
# during the same period from all the other locations
# not included in the feature data. For a survey area
# or river bassin these_features = feature_parent and 
# feature_level = parent_level
period_kwargs = {
    "period_data": fdx.period_data,
    "these_features": this_feature['slug'],
    "feature_level":this_feature['level'],
    "feature_parent":this_bassin,
    "parent_level": "river_bassin",
    "period_name": bassin_label,
    "unit_label": unit_label,
    "most_common": fdx.most_common.index
}
period_data = featuredata.PeriodResults(**period_kwargs)

# the rivers are considered separately
# select only the results from rivers
# this can be done by updating the fd_kwargs
fd_rivers = fd_kwargs.update({"water_type":"r"})
fdr = featuredata.Components(**fd_kwargs)
fdr.makeFeatureData()

# collects the summarized values for the feature data
# use this to generate the summary data for the survey area
# and the section for the rivers
admin_kwargs = {
    "data":fd,
    "dims_data":dfDims,
    "label": this_feature["name"],
    "feature_component": this_level,
    "date_range":start_end,
    **{"dfBeaches":dfBeaches}
}
admin_details = featuredata.AdministrativeSummary(**admin_kwargs)
admin_summary = admin_details.summaryObject()

# update the admin kwargs with river data to make the river summary
admin_kwargs.update({"data":fdr.feature_data})
admin_r_details = featuredata.AdministrativeSummary(**admin_kwargs)
admin_r_summary = admin_r_details.summaryObject()

# this defines the css rules for the note-book table displays
header_row = {'selector': 'th:nth-child(1)', 'props': f'background-color: #FFF;'}
even_rows = {"selector": 'tr:nth-child(even)', 'props': f'background-color: rgba(139, 69, 19, 0.08);'}
odd_rows = {'selector': 'tr:nth-child(odd)', 'props': 'background: #FFF;'}
table_font = {'selector': 'tr', 'props': 'font-size: 14px;'}
table_css_styles = [even_rows, odd_rows, table_font, header_row]


# pdf download is an option 
# reportlab is used to produce the document
# the arguments for the document are captured at run time
# capture for pdf content
pdf_link = f'/resources/pdfs/{this_feature["slug"]}.pdf'
pdfcomponents = []


# style definitions for pdf report
# section and paragraph formatting
# featuredata.title_style = ParagraphStyle(**{"name": "featuredata.title_style", "fontSize": 18, "fontName": "Helvetica"})
# featuredata.section_title = ParagraphStyle(**{"name": "featuredata.section_title", "fontSize": 16, "fontName": "Helvetica"})
# featuredata.caption_style = ParagraphStyle(**{"name": "featuredata.caption_style", "fontSize": 9, "fontName": "Times-Italic"})
# subfeaturedata.section_title = ParagraphStyle(**{"name": "sub_featuredata.section_title", "fontSize": 12, "fontName": "Helvetica"})
# featuredata.p_style = ParagraphStyle(**{"name": "content", "fontSize": 10, "fontName": "Times-Roman"})
# bold_block = ParagraphStyle(**{"name": "bold_block", "fontSize": 10, "fontName": "Times-Bold"})
# indented = ParagraphStyle(**{"name": "indented", "fontSize": 10, "fontName": "Times-Roman", "leftIndent":36})

# spacers 
# featuredata.larger_space = Spacer(1, .5*inch)
# featuredata.large_space = Spacer(1, .25*inch)
# featuredata.small_space = Spacer(1, .2*inch)
# smaller_space = Spacer(1, .15*inch)
# featuredata.smallest_space = Spacer(1, .12*inch)

# table definitions:
# table_header = ParagraphStyle(**{"name": "table_header", "fontSize": 8, "fontName": "Helvetica", "alignment":1})
# table_style = ParagraphStyle(**{"name": "table_style", "fontSize": 8, "fontName": "Helvetica"})
# styled_table_header = ParagraphStyle(**{"name": "table_header", "fontSize": 8, "fontName": "Helvetica", "alignment":1})
# table_style_centered = ParagraphStyle(**{"name": "table_style", "fontSize": 8, "fontName": "Helvetica", "alignment":1})
# table_style_right = ParagraphStyle(**{"name": "table_style", "fontSize": 8, "fontName": "Helvetica", "alignment":2})

# def featuredata.addToDoc(flowables, alist):
    
#     doc_components = [*alist, *flowables]
#     return doc_components


# def adminFormatNumericInteger(func=featuredata.thousandsSeparator, an_int: str=None, language: str=None):
#     # uses the method defined by func to apply numeric formatting according to the language variable
#     try:
#         data = func(an_int, language)
#     except OSError as err:
#         print("The function provided did not work", err)
#         raise
#     else:
#         return data


# def stringStartEndDate(func=featuredata.dateToYearAndMonth, date_format: str="%Y-%m-%d", lang: str = "de",  a_date: str=None,):
#     # uses the method defined by func to apply date formatting according to the language variable
    
#     try:
#         data = func(datetime.strptime(a_date, date_format), lang=lang)
#     except (TypeError, OSError) as err:
#         print("Is the date formatted the same as the date_format? Are you sure of the method provided?", err)
    
#     else:
#         return data


# def makeAdminSummaryStateMent(start, end, feature_name, language: str="de", admin_summary: dict=None):
#     # the admin summary can be called from the admin class. It has a specific construction. 
#     # use the data in the admin summary class to assemble string representation
    
#     start_date = stringStartEndDate(a_date=start)
#     end_date = stringStartEndDate(a_date=end)
#     n_samples = adminFormatNumericInteger(an_int=admin_summary["loc_date"])
#     total = adminFormatNumericInteger(an_int=admin_summary["quantity"])
#     population = adminFormatNumericInteger(an_int=admin_summary["population"])
    
#     if language != None:
#         phrase_one = f"Im Zeitraum von {start_date}  bis {end_date} wurden im Rahmen von {n_samples} Datenerhebungen insgesamt {total} Objekte entfernt und identifiziert."
#         phrase_two = f"Die Ergebnisse des {feature_name} umfassen {admin_summary['location']} Orte, {admin_summary['city']} Gemeinden und eine Gesamtbevölkerung von etwa {population} Einwohnenden."
        
#         return f'{phrase_one} {phrase_two}'
#     else:
#         return 'Check the language variable'
    
# def collectComponentLandMarks(admin_details, language="de"):
#     # the column headers are dependent on the language.
#     # using the admin_details class identify the component
#     # features of interest and have a language appropriate
#     # label.
    
#     component_list = []
    
#     if len(admin_details.lakesOfInterest()) > 0:
        
#         if language == "de":
#             header = "Seen"
        
#         if language == "fr":
#             header = "Lacs"
        
#         else:
#             header = "Lakes"
        
#         components = (header,  ", ".join(admin_details.lakes_of_interest))
        
#         component_list.append(components)
        
    
#     if len(admin_details.riversOfInterest()) > 0:
#         if language == "de":
#             header = "Fliessgewässer"
        
#         if language == "fr":
#             header = "Cours d'eaux"
        
#         else:
#             header = "Rivers"
        
#         components = (header,  ", ".join(admin_details.lakes_of_interest))
        
#         component_list.append(components)
        
#     if language == "de":
#             city_header = "Gemeinden"
        
#     if language == "fr":
#         city_header = "Communes"
        
#     else:
#         city_header = "Municipalities"
        
#     munis = (city_header, ", ".join(sorted(admin_details.populationKeys()["city"])))
       
    
#     component_list.append(munis)
    
#     return component_list
    
# class verticalText(Flowable):

#     '''Rotates a text in a table cell.'''

#     def __init__(self, text):
#         Flowable.__init__(self)
#         self.text = text

#     def draw(self):
#         canvas = self.canv
#         canvas.rotate(90)
#         fs = canvas._fontsize
#         canvas.translate(1, -fs/1.2)  # canvas._leading?
#         canvas.drawString(0, 0, self.text)

#     def wrap(self, aW, aH):
#         canv = self.canv
#         fn, fs = canv._fontname, canv._fontsize
#         return canv._leading, 1 + canv.stringWidth(self.text, fn, fs)
    
# def aStyledTable(data, header_style: Paragraph=styled_table_header, vertical_header: bool = False, data_style: Paragraph=table_style_centered, colWidths: []=None, style: []= None):
    
#     if vertical_header:
#         headers = [verticalText(x) for x in data.columns[1:]]
#         headers = [verticalText(" "), *headers]
#     else:
#         headers = [Paragraph(str(x), header_style)  for x in data.columns[1:]]
#         headers = [Paragraph(" ", table_style_centered) , *headers]
    
#     if style is None:
#         style=[
#         ('FONTNAME', (0,0), (-1,0), 'Helvetica'),
#         ('LINEBELOW',(0,0), (-1,0), 1, HexColor("#000")),
#         ('INNERGRID', (1,1), (-1,-1), 0.25, HexColor("#8b451330", hasAlpha=True)),
#         ('ROWBACKGROUNDS', (1,1), (-1,-1), [HexColor("#8b451320", hasAlpha=True), colors.white])
#         ]
    
#     new_rows = []
#     for a_row in data.values.tolist():
        
#         row_index = Paragraph(a_row[0], table_style_right)
#         row_data = [Paragraph(str(x), data_style) for x in a_row[1:]]
#         new_row = [row_index, *row_data]
#         new_rows.append(new_row)
        
#     new_table = [headers, *new_rows]
    
#     return Table(new_table, style=style, colWidths=colWidths, repeatRows=1)

# def colorGradient(x, cmap: str="YlOrBr", amin: int=0, amax: int=1):
#     a_cmap = plt.cm.get_cmap(cmap)
#     norm = mpl.colors.Normalize(vmin=amin, vmax=amax)
#     color = a_cmap(norm(x))
#     hex_color = mpl.colors.rgb2hex(color, keep_alpha=False)
    
#     return hex_color

# def stringifyValue(x):
#     if isinstance(x, str):
#         return x
#     else:
#         return str(x)
    
# def colorGradientTable(data, color_gradient: callable=colorGradient, column: int=None):
    
#     gradient_cells = TableStyle()
    
#     if column is None:
#         a_min = data.min().min()
#         a_max = data.max().max()
#         for i, row in enumerate(data.values):
#             for j, element in enumerate(row):
#                 hex_color = colorGradient(element, amin=a_min, amax=a_max)
#                 gradient_cells.add('BACKGROUND', (j+1, i+1), (j+1, i+1), hex_color)
    
#     elif isinstance(column, int) and column < len(data.values[0]):
#         for i, row in enumerate(data.values):
#             hex_color = colorGradient(row[column])
#             gradient_cells.add('BACKGROUND', (column+1,i+1), (column+1,i+1), hex_color)
#     else:
#         print("ouch")
    
#     return gradient_cells

# def featuredata.rotateText(x):
#     return 'writing-mode: vertical-lr; transform: rotate(-180deg);  padding:10px; margins:0; vertical-align: baseline;'
    

# pdf title and map
pdf_title = Paragraph(this_feature["name"], featuredata.title_style)
map_image =  Image(bassin_map, width=inch*7, height=inch*5, kind="proportional", hAlign= "LEFT")

pdfcomponents = featuredata.addToDoc([
    pdf_title,    
    featuredata.small_space,
    map_image
], pdfcomponents)

glue("feauture_name", this_feature["name"], display=False)
glue("pdf_link", pdf_link, display=False)
# Out:
# 'Bielersee'
# '/resources/pdfs/bielersee.pdf'

# %% [markdown]
# (bielersee_de)=
# # Bielersee
#
#
# {Download}`Download </resources/pdfs/bielersee.pdf>`

# %%
class Caption:
    
    position=''
    figure_number=0
    captions=[]
    start_caption = ""
    end_caption = '*'
    paragraphs = []
    
    def buildCaption(self):
        start_caption = f'*__{self.position}:__'
        new_string=''
        for line in self.captions:
            new_string += line
        end_caption = self.end_caption
        
        return f'{start_caption} {new_string}{end_caption}'
    
    def buildParagraph(self):
        new_string=''
        for line in self.paragraphs:
            new_string += line
        
        return new_string
        
            
map_caption = Caption()
map_caption.position = "Unten"
map_caption.captions = [
    "Karte des Erhebungsgebiets März 2020 bis Mai 2021. ",
    "Der Durchmesser der Punktsymbole entspricht dem Median der",
    "Abfallobjekte pro 100 Meter (p/100 m) am jeweiligen Erhebungsort."
]

# pdf output
map_caption.paragraphs = map_caption.captions
a_paragraph = map_caption.buildParagraph()

# add those sections
pdfcomponents = featuredata.addToDoc([Paragraph(a_paragraph, featuredata.caption_style)], pdfcomponents)

# %% [markdown]
# ```{figure} resources/maps/bielersee_scaled.jpeg
# ---
# name: bielersee_map
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_map>` Karte des Erhebungsgebiets März 2020 bis Mai 2021.  Der Durchmesser der Punktsymbole entspricht dem Median der Abfallobjekte pro 100 Meter (p/100 m) am jeweiligen Erhebungsort.

# %% [markdown]
# ## Erhebungsorte

# %%
an_admin_summary = featuredata.makeAdminSummaryStateMent(start_date, end_date, this_feature["name"], admin_summary=admin_summary)
                      
# collect component features and land marks
feature_components = featuredata.collectComponentLandMarks(admin_details, language="de")

# markdown output
components_markdown = [f'*{x[0]}*\n\n>{x[1]}\n\n' for x in feature_components]

# add the admin summary to the pdf
pdfcomponents = featuredata.addToDoc([
    featuredata.large_space,
    Paragraph("Erhebungsorte", featuredata.section_title), 
    featuredata.small_space,
    Paragraph(an_admin_summary , featuredata.p_style),
    
    
], pdfcomponents)

# put that all together:
lake_string = F"""
{an_admin_summary}

{"".join(components_markdown)}
"""
md(lake_string)
# Out:
# Im Zeitraum von März 2020  bis Mai 2021 wurden im Rahmen von 38 Datenerhebungen insgesamt 4,477 Objekte entfernt und identifiziert. Die Ergebnisse des Bielersee umfassen 10 Orte, 8 Gemeinden und eine Gesamtbevölkerung von etwa 70,810 Einwohnenden.
#
# *Lakes*
#
# >Bielersee
#
# *Municipalities*
#
# >Biel/Bienne, Erlach, Gals, Le Landeron, Ligerz, Lüscherz, Nidau, Vinelz

# %% [markdown]
# ### Kumulative Gesamtmengen nach Gemeinden

# %%
# add section to pdf
pdfcomponents = featuredata.addToDoc([featuredata.large_space, Paragraph("Kumulative Gesamtmengen nach Gemeinden", featuredata.section_title)], pdfcomponents)

# the .pdf output is generated in parallel
# this is the same as if it were on the backend where we would
# have a specific api endpoint for .pdf requests. 
dims_table = admin_details.dimensionalSummary()
dims_table.sort_values(by=["quantity"], ascending=False, inplace=True)

# apply language
dims_table.rename(columns=featuredata.dims_table_columns_de, inplace=True)

# convert to kilos
dims_table["Plastik (Kg)"] = dims_table["Plastik (Kg)"]/1000

# save a copyt of the dims_table for working
# formattinr to pdf will turn the numerics to strings
# which eliminates any further calclations
dims_df =  dims_table.copy()

# these columns need formatting for locale
thousands_separated = ["Fläche (m2)", "Länge (m)", "Erhebungen", "Objekte (St.)"]
replace_decimal = ["Plastik (Kg)", "Gesamtgewicht (Kg)"]

# format the dimensional summary for .pdf and add to components
dims_table[thousands_separated] = dims_table[thousands_separated].applymap(lambda x: featuredata.thousandsSeparator(int(x), "de"))
dims_table[replace_decimal] = dims_table[replace_decimal].applymap(lambda x: featuredata.replaceDecimal(str(round(x,2))))
dims_table.reset_index(inplace=True)

# a caption for the figure
dims_table_caption = f'{this_feature["name"]}: kumulierten Gewichte  und Masse für die Gemeinden'

# pdf components                 
d_chart = featuredata.aStyledTable(dims_table, colWidths=[1.2*inch] + [1.2*inch] + [None]*len(dims_table.columns))
d_capt = Paragraph(dims_table_caption, featuredata.caption_style)
pdfcomponents = featuredata.addToDoc([featuredata.small_space, d_chart, featuredata.smallest_space, d_capt, PageBreak()], pdfcomponents)

# this formats the table through the data frame
dims_df["Plastik (Kg)"] = dims_df["Plastik (Kg)"].round(2)
dims_df["Gesamtgewicht (Kg)"] = dims_df["Gesamtgewicht (Kg)"].round(2)
dims_df[thousands_separated] = dims_df[thousands_separated].astype("int")

# set the index name to None so it doesn't show in the columns
dims_df.index.name = None
dims_df.columns.name = None

# this applies formatting to the specifc column based on
# the language.
dims_table_formatter = {
    "Plastik (Kg)": lambda x: featuredata.replaceDecimal(x, "de"),
    "Gesamtgewicht (Kg)": lambda x: featuredata.replaceDecimal(x, "de"),
    "Fläche (m2)": lambda x: featuredata.thousandsSeparator(int(x), "de"),
    "Länge (m)": lambda x: featuredata.thousandsSeparator(int(x), "de"),
    "Erhebungen": lambda x: featuredata.thousandsSeparator(int(x), "de"),
    "Objekte (St.)": lambda x: featuredata.thousandsSeparator(int(x), "de")
}

# use the caption from the .pdf for the online figure
glue("bielersee_dims_table_caption",dims_table_caption, display=False)

# apply formatting and styles to dataframe
q = dims_df.style.format(formatter=dims_table_formatter).set_table_styles(table_css_styles)

# capture the figure before display and give it a reference number and caption
figure_name='bielersee_dims_table'
glue(figure_name, q, display=False)
# Out:
# 'Bielersee: kumulierten Gewichte  und Masse für die Gemeinden'
# <style type="text/css">
# #T_4a093 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_4a093 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_4a093 tr {
#   font-size: 14px;
# }
# #T_4a093 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_4a093">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a093_level0_col0" class="col_heading level0 col0" >Gesamtgewicht (Kg)</th>
#       <th id="T_4a093_level0_col1" class="col_heading level0 col1" >Plastik (Kg)</th>
#       <th id="T_4a093_level0_col2" class="col_heading level0 col2" >Fläche (m2)</th>
#       <th id="T_4a093_level0_col3" class="col_heading level0 col3" >Länge (m)</th>
#       <th id="T_4a093_level0_col4" class="col_heading level0 col4" >Erhebungen</th>
#       <th id="T_4a093_level0_col5" class="col_heading level0 col5" >Objekte (St.)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a093_level0_row0" class="row_heading level0 row0" >Bielersee</th>
#       <td id="T_4a093_row0_col0" class="data row0 col0" >13,1</td>
#       <td id="T_4a093_row0_col1" class="data row0 col1" >6,67</td>
#       <td id="T_4a093_row0_col2" class="data row0 col2" >6 343</td>
#       <td id="T_4a093_row0_col3" class="data row0 col3" >1 247</td>
#       <td id="T_4a093_row0_col4" class="data row0 col4" >38</td>
#       <td id="T_4a093_row0_col5" class="data row0 col5" >4 477</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row1" class="row_heading level0 row1" >Biel/Bienne</th>
#       <td id="T_4a093_row1_col0" class="data row1 col0" >7,34</td>
#       <td id="T_4a093_row1_col1" class="data row1 col1" >3,69</td>
#       <td id="T_4a093_row1_col2" class="data row1 col2" >4 584</td>
#       <td id="T_4a093_row1_col3" class="data row1 col3" >580</td>
#       <td id="T_4a093_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_4a093_row1_col5" class="data row1 col5" >2 969</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row2" class="row_heading level0 row2" >Vinelz</th>
#       <td id="T_4a093_row2_col0" class="data row2 col0" >3,1</td>
#       <td id="T_4a093_row2_col1" class="data row2 col1" >1,86</td>
#       <td id="T_4a093_row2_col2" class="data row2 col2" >536</td>
#       <td id="T_4a093_row2_col3" class="data row2 col3" >238</td>
#       <td id="T_4a093_row2_col4" class="data row2 col4" >12</td>
#       <td id="T_4a093_row2_col5" class="data row2 col5" >898</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row3" class="row_heading level0 row3" >Lüscherz</th>
#       <td id="T_4a093_row3_col0" class="data row3 col0" >1,72</td>
#       <td id="T_4a093_row3_col1" class="data row3 col1" >0,33</td>
#       <td id="T_4a093_row3_col2" class="data row3 col2" >538</td>
#       <td id="T_4a093_row3_col3" class="data row3 col3" >257</td>
#       <td id="T_4a093_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_4a093_row3_col5" class="data row3 col5" >202</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row4" class="row_heading level0 row4" >Ligerz</th>
#       <td id="T_4a093_row4_col0" class="data row4 col0" >0,3</td>
#       <td id="T_4a093_row4_col1" class="data row4 col1" >0,29</td>
#       <td id="T_4a093_row4_col2" class="data row4 col2" >49</td>
#       <td id="T_4a093_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_4a093_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_4a093_row4_col5" class="data row4 col5" >143</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row5" class="row_heading level0 row5" >Erlach</th>
#       <td id="T_4a093_row5_col0" class="data row5 col0" >0,05</td>
#       <td id="T_4a093_row5_col1" class="data row5 col1" >0,05</td>
#       <td id="T_4a093_row5_col2" class="data row5 col2" >374</td>
#       <td id="T_4a093_row5_col3" class="data row5 col3" >57</td>
#       <td id="T_4a093_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_4a093_row5_col5" class="data row5 col5" >101</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row6" class="row_heading level0 row6" >Nidau</th>
#       <td id="T_4a093_row6_col0" class="data row6 col0" >0,13</td>
#       <td id="T_4a093_row6_col1" class="data row6 col1" >0,0</td>
#       <td id="T_4a093_row6_col2" class="data row6 col2" >105</td>
#       <td id="T_4a093_row6_col3" class="data row6 col3" >25</td>
#       <td id="T_4a093_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_4a093_row6_col5" class="data row6 col5" >63</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row7" class="row_heading level0 row7" >Le Landeron</th>
#       <td id="T_4a093_row7_col0" class="data row7 col0" >0,04</td>
#       <td id="T_4a093_row7_col1" class="data row7 col1" >0,04</td>
#       <td id="T_4a093_row7_col2" class="data row7 col2" >93</td>
#       <td id="T_4a093_row7_col3" class="data row7 col3" >37</td>
#       <td id="T_4a093_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_4a093_row7_col5" class="data row7 col5" >53</td>
#     </tr>
#     <tr>
#       <th id="T_4a093_level0_row8" class="row_heading level0 row8" >Gals</th>
#       <td id="T_4a093_row8_col0" class="data row8 col0" >0,43</td>
#       <td id="T_4a093_row8_col1" class="data row8 col1" >0,4</td>
#       <td id="T_4a093_row8_col2" class="data row8 col2" >64</td>
#       <td id="T_4a093_row8_col3" class="data row8 col3" >38</td>
#       <td id="T_4a093_row8_col4" class="data row8 col4" >2</td>
#       <td id="T_4a093_row8_col5" class="data row8 col5" >48</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ```{glue:figure} bielersee_dims_table
# ---
# name: 'bielersee_dims_table'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_dims_table>` {glue:text}`bielersee_dims_table_caption`

# %% [markdown]
# ### Verteilung der Erhebungsergebnisse

# %%
# figure caption
sample_total_notes = f'Links: {this_feature["name"]}, {featuredata.dateToYearAndMonth(datetime.strptime(start_date, date_format), lang=date_lang)} bis {featuredata.dateToYearAndMonth(datetime.strptime(end_date, date_format), lang=date_lang)}, n = {admin_summary["loc_date"]}. Rechts: empirische Verteilungsfunktion der Erhebungsergebnisse {this_feature["name"]}.'
glue("sample_total_notes", sample_total_notes, display=False)

dx = period_data.parentSampleTotals(parent=False)

months = mdates.MonthLocator(interval=1)
months_fmt = mdates.DateFormatter("%b")
days = mdates.DayLocator(interval=7)

# get the monthly or quarterly results for the feature
rsmp = fdx.sample_totals.set_index("date")
resample_plot, rate = featuredata.quarterlyOrMonthlyValues(rsmp, this_feature["name"], vals=unit_label)

fig, axs = plt.subplots(1,2, figsize=(10,5))

# the survey totals by day
ax = axs[0]

# feature surveys
sns.scatterplot(data=dx, x="date", y=unit_label, label=top, color="black", alpha=0.4,  ax=ax)
# all other surveys
sns.scatterplot(data=fdx.sample_totals, x="date", y=unit_label, label=this_feature["name"], color="red", s=34, ec="white", ax=ax)
# monthly or quaterly plot
sns.lineplot(data=resample_plot, x=resample_plot.index, y=resample_plot, label=F"{this_feature['name']}: monatlicher Medianwert", color="magenta", ax=ax)
# axis formatting
ax.set_ylabel(unit_label, **ck.xlab_k14)
ax.set_xlabel("")
ax.xaxis.set_minor_locator(days)
ax.xaxis.set_major_formatter(months_fmt)
ax.set_ylim(-50, 2000)
# call the legend
ax.legend()

# the cumlative distributions:
axtwo = axs[1]

# the feature of interest
feature_ecd = featuredata.ecdfOfAColumn(fdx.sample_totals, unit_label)    
sns.lineplot(x=feature_ecd["x"], y=feature_ecd["y"], color="darkblue", ax=axtwo, label=this_feature["name"])

# the other features
other_features = featuredata.ecdfOfAColumn(dx, unit_label)
sns.lineplot(x=other_features["x"], y=other_features["y"], color="magenta", label=top, linewidth=1, ax=axtwo)

axtwo.set_xlabel(unit_label, **ck.xlab_k14)
axtwo.set_ylabel("Verhältnis der Erhebungen", **ck.xlab_k14)
axtwo.set_xlim(0, 3000)

axtwo.xaxis.set_major_locator(MultipleLocator(500))
axtwo.xaxis.set_minor_locator(MultipleLocator(100))
axtwo.yaxis.set_major_locator(MultipleLocator(.1))
axtwo.grid(which="minor", visible=True, axis="x", linestyle="--", linewidth=1)

figure_name = "bielersee_sample_totals"
sample_totals_file_name = f'{save_fig_prefix}{figure_name}.jpeg'
save_figure_kwargs.update({"fname":sample_totals_file_name})

plt.tight_layout()
plt.savefig(**save_figure_kwargs)
glue("bielersee_sample_totals", fig, display=False)
plt.close()
# Out:
# 'Links: Bielersee, März 2020 bis Mai 2021, n = 38. Rechts: empirische Verteilungsfunktion der Erhebungsergebnisse Bielersee.'

# %% [markdown]
# ```{glue:figure} bielersee_sample_totals
# ---
# name: 'bielersee_sample_totals'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_sample_totals>` {glue:text}`sample_total_notes`

# %% [markdown]
# ### Zusammengefasste Daten und Materialarten

# %%
# figure caption
summary_of_survey_totals = f'Zusammenfassung der Daten aller Erhebungen am {this_feature["name"]}. Gefundene Materialarten am {this_feature["name"]} in Stückzahlen und als prozentuale Anteile (stückzahlbezogen).'

# %%
# add to pdf
s_totals = Image(sample_totals_file_name, width=inch*6, height=inch*4.8, kind="proportional", hAlign= "LEFT")
s_totals_caption = Paragraph(sample_total_notes, featuredata.caption_style)
pdfcomponents = featuredata.addToDoc([Paragraph("Verteilung der Erhebungsergebnisse", featuredata.subsection_title), featuredata.small_space, s_totals, s_totals_caption], pdfcomponents)

csx = fdx.sample_summary.copy()

combined_summary =[(x, featuredata.thousandsSeparator(int(csx[x]), language)) for x in csx.index]

# the materials table
fd_mat_totals = fdx.material_summary.copy()
fd_mat_totals = featuredata.fmtPctOfTotal(fd_mat_totals, around=0)

# applly new column names for printing
cols_to_use = {"material":"Material","quantity":"Objekte (St.)", "% of total":"Anteil"}
fd_mat_t = fd_mat_totals[cols_to_use.keys()].values
fd_mat_t = [(x[0], featuredata.thousandsSeparator(int(x[1]), language), x[2]) for x in fd_mat_t]

# make tables
fig, axs = plt.subplots(1,2, figsize=(7, len(combined_summary)*.4))

# summary table
# names for the table columns
a_col = [this_feature["name"], "Total"]

axone = axs[0]
sut.hide_spines_ticks_grids(axone)

table_two = sut.make_a_table(axone, combined_summary,  colLabels=a_col, colWidths=[.75,.25],  bbox=[0,0,1,1], **{"loc":"lower center"})
table_two.get_celld()[(0,0)].get_text().set_text(" ")
table_two.set_fontsize(10)

# material table
axtwo = axs[1]
axtwo.set_xlabel(" ")
sut.hide_spines_ticks_grids(axtwo)

table_three = sut.make_a_table(axtwo, fd_mat_t,  colLabels=list(cols_to_use.values()), colWidths=[.4, .4,.2],  bbox=[0,0,1,1], **{"loc":"lower center"})
table_three.get_celld()[(0,0)].get_text().set_text(" ")
table_three.set_fontsize(10)
plt.tight_layout()
plt.subplots_adjust(wspace=0.1)
plt.margins(0, 0)
figure_name = "bielersee_sample_summaries"
sample_summaries_file_name = f'{save_fig_prefix}{figure_name}.jpeg'
save_figure_kwargs.update({"fname":sample_summaries_file_name})

plt.savefig(**save_figure_kwargs)


glue('summary_of_survey_totals', summary_of_survey_totals, display=False)


glue(figure_name, fig, display=False)
plt.close()
# Out:
# 'Zusammenfassung der Daten aller Erhebungen am Bielersee. Gefundene Materialarten am Bielersee in Stückzahlen und als prozentuale Anteile (stückzahlbezogen).'

# %% [markdown]
# ```{glue:figure} bielersee_sample_summaries
# ---
# name: 'bielersee_sample_summaries'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_sample_summaries>` {glue:text}`summary_of_survey_totals`

# %% [markdown]
# ## Die am häufigsten gefundenen Objekte
#
# Die am häufigsten gefundenen Objekte sind die zehn mengenmässig am meisten vorkommenden Objekte und/oder Objekte, die in mindestens 50 % aller Datenerhebungen identifiziert wurden (Häufigkeitsrate)

# %%
# add summary tables to pdf
samp_mat_subsection = Paragraph("Zusammengefasste Daten und Materialarten", featuredata.subsection_title)
samp_material_table = Image(sample_summaries_file_name , width=inch*6, height=inch*4.8, kind="proportional", hAlign= "LEFT")
samp_material_caption = Paragraph(summary_of_survey_totals, featuredata.caption_style)

new_components = [
    featuredata.large_space,
    samp_mat_subsection,
    featuredata.small_space,
    samp_material_table,
    samp_material_caption,
    PageBreak() 
]

pdfcomponents = featuredata.addToDoc([featuredata.large_space, samp_mat_subsection, featuredata.small_space, samp_material_table, samp_material_caption, PageBreak() ], pdfcomponents)

# the most common results
most_common_display = fdx.most_common

# language appropriate columns
cols_to_use = featuredata.most_common_objects_table_de
cols_to_use.update({unit_label:unit_label})

# data for display
most_common_display.rename(columns=cols_to_use, inplace=True)
most_common_display = most_common_display[cols_to_use.values()].copy()
most_common_display = most_common_display.set_index("Objekt", drop=True)

# .pdf output
data = most_common_display.copy()
data["Anteil"] = data["Anteil"].map(lambda x: f"{int(x)}%")
data['Objekte (St.)'] = data['Objekte (St.)'].map(lambda x:featuredata.thousandsSeparator(x, language))
data["fail rate"] = data['Häufigkeitsrate'].map(lambda x: f"{x}%")
data[unit_label] = data[unit_label].map(lambda x: featuredata.replaceDecimal(round(x,1)))

pdf_mc_table  = featuredata.aStyledTable(data.reset_index(), colWidths=[2.3*inch] + [None]*len(data.columns))

# get percent of total to make the caption string
m_common_percent_of_total = fdx.most_common['Objekte (St.)'].sum()/fdx.code_summary['quantity'].sum()

mc_caption_string = [
    f'Häufigste Objekte im {this_feature["name"]}: ',
    'd. h. Objekte mit einer Häufigkeitsrate von mindestens 50% und/oder ',
    f'Top Ten nach Anzahl. Zusammengenommen machen die häufigsten Objekte {int(m_common_percent_of_total*100)}% ',
    f'aller gefundenen Objekte aus. Anmerkung: {unit_label} = Medianwert der Erhebung.'
]

mc_caption_string = "".join(mc_caption_string)

most_common_display.index.name = None
most_common_display.columns.name = None

# set pandas display
aformatter = {
    "Anteil":lambda x: f"{int(x)}%",
    f"{unit_label}": lambda x: featuredata.replaceDecimal(x, "de"),
    "Häufigkeitsrate": lambda x: f"{int(x)}%",   
    "Objekte (St.)": lambda x: featuredata.thousandsSeparator(int(x), "de")
}

mcd = most_common_display.style.format(aformatter).set_table_styles(table_css_styles)
glue('bielersee_most_common_caption', mc_caption_string, display=False)
glue('bielersee_most_common_tables', mcd, display=False)
# Out:
# 'Häufigste Objekte im Bielersee: d. h. Objekte mit einer Häufigkeitsrate von mindestens 50% und/oder Top Ten nach Anzahl. Zusammengenommen machen die häufigsten Objekte 73% aller gefundenen Objekte aus. Anmerkung: p/100 m = Medianwert der Erhebung.'
# <style type="text/css">
# #T_05dc8 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_05dc8 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_05dc8 tr {
#   font-size: 14px;
# }
# #T_05dc8 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_05dc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05dc8_level0_col0" class="col_heading level0 col0" >Objekte (St.)</th>
#       <th id="T_05dc8_level0_col1" class="col_heading level0 col1" >Anteil</th>
#       <th id="T_05dc8_level0_col2" class="col_heading level0 col2" >Häufigkeitsrate</th>
#       <th id="T_05dc8_level0_col3" class="col_heading level0 col3" >p/100 m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05dc8_level0_row0" class="row_heading level0 row0" >Fragmentierte Kunststoffe</th>
#       <td id="T_05dc8_row0_col0" class="data row0 col0" >746</td>
#       <td id="T_05dc8_row0_col1" class="data row0 col1" >16%</td>
#       <td id="T_05dc8_row0_col2" class="data row0 col2" >97%</td>
#       <td id="T_05dc8_row0_col3" class="data row0 col3" >53,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row1" class="row_heading level0 row1" >Zigarettenfilter</th>
#       <td id="T_05dc8_row1_col0" class="data row1 col0" >744</td>
#       <td id="T_05dc8_row1_col1" class="data row1 col1" >16%</td>
#       <td id="T_05dc8_row1_col2" class="data row1 col2" >78%</td>
#       <td id="T_05dc8_row1_col3" class="data row1 col3" >9,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row2" class="row_heading level0 row2" >Snack-Verpackungen</th>
#       <td id="T_05dc8_row2_col0" class="data row2 col0" >325</td>
#       <td id="T_05dc8_row2_col1" class="data row2 col1" >7%</td>
#       <td id="T_05dc8_row2_col2" class="data row2 col2" >86%</td>
#       <td id="T_05dc8_row2_col3" class="data row2 col3" >21,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row3" class="row_heading level0 row3" >Industriefolie (Kunststoff)</th>
#       <td id="T_05dc8_row3_col0" class="data row3 col0" >300</td>
#       <td id="T_05dc8_row3_col1" class="data row3 col1" >6%</td>
#       <td id="T_05dc8_row3_col2" class="data row3 col2" >89%</td>
#       <td id="T_05dc8_row3_col3" class="data row3 col3" >18,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row4" class="row_heading level0 row4" >Getränke Glasflasche, Stücke</th>
#       <td id="T_05dc8_row4_col0" class="data row4 col0" >176</td>
#       <td id="T_05dc8_row4_col1" class="data row4 col1" >3%</td>
#       <td id="T_05dc8_row4_col2" class="data row4 col2" >68%</td>
#       <td id="T_05dc8_row4_col3" class="data row4 col3" >5,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row5" class="row_heading level0 row5" >Expandiertes Polystyrol</th>
#       <td id="T_05dc8_row5_col0" class="data row5 col0" >173</td>
#       <td id="T_05dc8_row5_col1" class="data row5 col1" >3%</td>
#       <td id="T_05dc8_row5_col2" class="data row5 col2" >63%</td>
#       <td id="T_05dc8_row5_col3" class="data row5 col3" >5,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row6" class="row_heading level0 row6" >Verpackungsfolien, nicht für Lebensmittel</th>
#       <td id="T_05dc8_row6_col0" class="data row6 col0" >173</td>
#       <td id="T_05dc8_row6_col1" class="data row6 col1" >3%</td>
#       <td id="T_05dc8_row6_col2" class="data row6 col2" >63%</td>
#       <td id="T_05dc8_row6_col3" class="data row6 col3" >9,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row7" class="row_heading level0 row7" >Tabak; Kunststoffverpackungen, Behälter</th>
#       <td id="T_05dc8_row7_col0" class="data row7 col0" >92</td>
#       <td id="T_05dc8_row7_col1" class="data row7 col1" >2%</td>
#       <td id="T_05dc8_row7_col2" class="data row7 col2" >73%</td>
#       <td id="T_05dc8_row7_col3" class="data row7 col3" >5,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row8" class="row_heading level0 row8" >Schaumstoff EVA (flexibler Kunststoff)</th>
#       <td id="T_05dc8_row8_col0" class="data row8 col0" >92</td>
#       <td id="T_05dc8_row8_col1" class="data row8 col1" >2%</td>
#       <td id="T_05dc8_row8_col2" class="data row8 col2" >31%</td>
#       <td id="T_05dc8_row8_col3" class="data row8 col3" >0,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row9" class="row_heading level0 row9" >Kunststoff-Bauabfälle</th>
#       <td id="T_05dc8_row9_col0" class="data row9 col0" >89</td>
#       <td id="T_05dc8_row9_col1" class="data row9 col1" >1%</td>
#       <td id="T_05dc8_row9_col2" class="data row9 col2" >71%</td>
#       <td id="T_05dc8_row9_col3" class="data row9 col3" >4,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row10" class="row_heading level0 row10" >Feuerwerkskörper; Raketenkappen</th>
#       <td id="T_05dc8_row10_col0" class="data row10 col0" >76</td>
#       <td id="T_05dc8_row10_col1" class="data row10 col1" >1%</td>
#       <td id="T_05dc8_row10_col2" class="data row10 col2" >68%</td>
#       <td id="T_05dc8_row10_col3" class="data row10 col3" >4,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row11" class="row_heading level0 row11" >Schaumstoffverpackungen/Isolierung</th>
#       <td id="T_05dc8_row11_col0" class="data row11 col0" >72</td>
#       <td id="T_05dc8_row11_col1" class="data row11 col1" >1%</td>
#       <td id="T_05dc8_row11_col2" class="data row11 col2" >50%</td>
#       <td id="T_05dc8_row11_col3" class="data row11 col3" >1,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row12" class="row_heading level0 row12" >Industriepellets (Nurdles)</th>
#       <td id="T_05dc8_row12_col0" class="data row12 col0" >71</td>
#       <td id="T_05dc8_row12_col1" class="data row12 col1" >1%</td>
#       <td id="T_05dc8_row12_col2" class="data row12 col2" >60%</td>
#       <td id="T_05dc8_row12_col3" class="data row12 col3" >2,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row13" class="row_heading level0 row13" >Wattestäbchen/Tupfer</th>
#       <td id="T_05dc8_row13_col0" class="data row13 col0" >68</td>
#       <td id="T_05dc8_row13_col1" class="data row13 col1" >1%</td>
#       <td id="T_05dc8_row13_col2" class="data row13 col2" >50%</td>
#       <td id="T_05dc8_row13_col3" class="data row13 col3" >1,0</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row14" class="row_heading level0 row14" >Verpackungen aus Aluminiumfolie</th>
#       <td id="T_05dc8_row14_col0" class="data row14 col0" >61</td>
#       <td id="T_05dc8_row14_col1" class="data row14 col1" >1%</td>
#       <td id="T_05dc8_row14_col2" class="data row14 col2" >60%</td>
#       <td id="T_05dc8_row14_col3" class="data row14 col3" >2,5</td>
#     </tr>
#     <tr>
#       <th id="T_05dc8_level0_row15" class="row_heading level0 row15" >Sonstiges medizinisches Material</th>
#       <td id="T_05dc8_row15_col0" class="data row15 col0" >29</td>
#       <td id="T_05dc8_row15_col1" class="data row15 col1" >0%</td>
#       <td id="T_05dc8_row15_col2" class="data row15 col2" >50%</td>
#       <td id="T_05dc8_row15_col3" class="data row15 col3" >1,0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ```{glue:figure} bielersee_most_common_tables
# ---
# name: 'bielersee_most_common_tables'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_most_common_tables>` {glue:text}`bielersee_most_common_caption`

# %% [markdown]
# ### Die am häufigsten gefundenen Objekte nach Gemeinden

# %%
# add new section to pdf
mc_section_title = Paragraph("Die am häufigsten gefundenen Objekte", featuredata.section_title)
para_g = "Die am häufigsten gefundenen Objekte sind die zehn mengenmässig am meisten vorkommenden Objekte und/oder Objekte, die in mindestens 50 % aller Datenerhebungen identifiziert wurden (Häufigkeitsrate)"
mc_section_para = Paragraph(para_g, featuredata.p_style)
mc_table_cap = Paragraph(mc_caption_string, featuredata.caption_style)
mc_heatmap_title = Paragraph("Die am häufigsten gefundenen Objekte nach Gemeinden", featuredata.subsection_title)


new_components = [
    mc_section_title,
    featuredata.small_space,
    mc_section_para,
    featuredata.large_space,
    pdf_mc_table,
    featuredata.smallest_space,
    mc_table_cap,
    featuredata.small_space,    
    mc_heatmap_title,
    featuredata.large_space
]
pdfcomponents = featuredata.addToDoc(new_components, pdfcomponents)

mc_heat_map_caption = f'Median {unit_label} der häufigsten Objekte am {this_feature["name"]}.'

# calling componentsMostCommon gets the results for the most common codes
# at the component level
components = fdx.componentMostCommonPcsM()

# pivot that and quash the hierarchal column index that is created when the table is pivoted
mc_comp = components[["item", unit_label, "city"]].pivot(columns="city", index="item")
mc_comp.columns = mc_comp.columns.get_level_values(1)

# the aggregated total of the feature is taken from the most common objects table
mc_feature = fdx.most_common[unit_label]
mc_feature = featuredata.changeSeriesIndexLabels(mc_feature, {x:fdx.dMap.loc[x] for x in mc_feature.index})

# aggregated totals of the parent this is derived from the arguments in kwargs
mc_parent = period_data.parentMostCommon(parent=True)
mc_parent = featuredata.changeSeriesIndexLabels(mc_parent, {x:fdx.dMap.loc[x] for x in mc_parent.index})

# the aggregated totals of all the period data
mc_period = period_data.parentMostCommon(parent=False)
mc_period = featuredata.changeSeriesIndexLabels(mc_period, {x:fdx.dMap.loc[x] for x in mc_period.index})

# add the feature, bassin_label and period results to the components table
mc_comp[this_feature["name"]]= mc_feature
mc_comp[bassin_label] = mc_parent
mc_comp[top] = mc_period

# pdf out put
heat_map_caption = Paragraph(mc_heat_map_caption, featuredata.caption_style)
heat_map_gradient = featuredata.colorGradientTable(mc_comp)

mc_heat_map  = featuredata.aStyledTable(mc_comp.reset_index(), vertical_header=True, colWidths=[2.3*inch] + [None]*len(mc_comp.columns))
heat_map_gradient = featuredata.colorGradientTable(mc_comp)
mc_heat_map.setStyle(heat_map_gradient)
# pdfcomponents = featuredata.addToDoc(mc_heat_map, pdfcomponents)
# mc_heat_map.setStyle(heat_map_gradient)
new_components = [
    mc_heat_map,
    featuredata.smallest_space,
    heat_map_caption,
    featuredata.large_space,
]

pdfcomponents = featuredata.addToDoc(new_components, pdfcomponents)

# notebook display style
aformatter = {x: featuredata.replaceDecimal for x in mc_comp.columns}
mcd = mc_comp.style.format(aformatter).set_table_styles(table_css_styles)
mcd = mcd.background_gradient(axis=None, vmin=mc_comp.min().min(), vmax=mc_comp.max().max(), cmap="YlOrBr")

# remove the index name and column name labels
mcd.index.name = None
mcd.columns.name = None

# rotate the text on the header row
# the .applymap_index method in the
# df.styler module is used for this
mcd = mcd.applymap_index(featuredata.rotateText, axis=1)

# display markdown html
glue('mc_heat_map_caption', mc_heat_map_caption, display=False)

glue('bielersee_most_common_heat_map', mcd, display=False)
# Out:
# 'Median p/100 m der häufigsten Objekte am Bielersee.'
# <style type="text/css">
# #T_66dd0 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_66dd0 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_66dd0 tr {
#   font-size: 14px;
# }
# #T_66dd0 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_66dd0_row0_col0, #T_66dd0_row4_col3, #T_66dd0_row11_col3, #T_66dd0_row13_col3 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_66dd0_row0_col1, #T_66dd0_row1_col0, #T_66dd0_row3_col1, #T_66dd0_row6_col1, #T_66dd0_row9_col5, #T_66dd0_row10_col5, #T_66dd0_row13_col1 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_66dd0_row0_col2, #T_66dd0_row0_col5, #T_66dd0_row0_col7, #T_66dd0_row1_col2, #T_66dd0_row1_col5, #T_66dd0_row1_col6, #T_66dd0_row1_col9, #T_66dd0_row1_col10, #T_66dd0_row3_col3, #T_66dd0_row4_col1, #T_66dd0_row5_col1, #T_66dd0_row5_col2, #T_66dd0_row5_col3, #T_66dd0_row5_col4, #T_66dd0_row5_col5, #T_66dd0_row5_col9, #T_66dd0_row5_col10, #T_66dd0_row6_col2, #T_66dd0_row6_col4, #T_66dd0_row6_col5, #T_66dd0_row6_col9, #T_66dd0_row7_col1, #T_66dd0_row7_col3, #T_66dd0_row7_col5, #T_66dd0_row7_col6, #T_66dd0_row7_col7, #T_66dd0_row7_col8, #T_66dd0_row7_col9, #T_66dd0_row7_col10, #T_66dd0_row8_col1, #T_66dd0_row8_col2, #T_66dd0_row8_col3, #T_66dd0_row8_col5, #T_66dd0_row8_col6, #T_66dd0_row8_col7, #T_66dd0_row8_col9, #T_66dd0_row10_col1, #T_66dd0_row10_col6, #T_66dd0_row10_col7, #T_66dd0_row10_col9, #T_66dd0_row10_col10, #T_66dd0_row11_col1, #T_66dd0_row11_col5, #T_66dd0_row11_col6, #T_66dd0_row11_col9, #T_66dd0_row11_col10, #T_66dd0_row12_col1, #T_66dd0_row12_col3, #T_66dd0_row12_col5, #T_66dd0_row12_col7, #T_66dd0_row12_col10, #T_66dd0_row13_col2, #T_66dd0_row13_col5, #T_66dd0_row13_col9, #T_66dd0_row13_col10, #T_66dd0_row14_col3, #T_66dd0_row14_col5, #T_66dd0_row14_col6, #T_66dd0_row14_col7, #T_66dd0_row14_col9, #T_66dd0_row15_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_66dd0_row0_col3, #T_66dd0_row1_col7, #T_66dd0_row5_col6, #T_66dd0_row9_col9 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_66dd0_row0_col4, #T_66dd0_row0_col8, #T_66dd0_row3_col8, #T_66dd0_row10_col4, #T_66dd0_row11_col2, #T_66dd0_row11_col7, #T_66dd0_row11_col8, #T_66dd0_row14_col2 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_66dd0_row0_col6, #T_66dd0_row0_col9, #T_66dd0_row1_col8, #T_66dd0_row5_col0, #T_66dd0_row6_col6, #T_66dd0_row6_col8, #T_66dd0_row12_col6, #T_66dd0_row15_col5, #T_66dd0_row15_col7 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_66dd0_row0_col10, #T_66dd0_row1_col3, #T_66dd0_row4_col5, #T_66dd0_row4_col9, #T_66dd0_row4_col10, #T_66dd0_row9_col1 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_66dd0_row1_col1, #T_66dd0_row3_col7, #T_66dd0_row9_col10, #T_66dd0_row15_col2, #T_66dd0_row15_col8 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_66dd0_row1_col4, #T_66dd0_row9_col2, #T_66dd0_row12_col4, #T_66dd0_row14_col4 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_66dd0_row2_col0 {
#   background-color: #fee18c;
#   color: #000000;
# }
# #T_66dd0_row2_col1 {
#   background-color: #fee390;
#   color: #000000;
# }
# #T_66dd0_row2_col2 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_66dd0_row2_col3 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_66dd0_row2_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_66dd0_row2_col5 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_66dd0_row2_col6 {
#   background-color: #fecf67;
#   color: #000000;
# }
# #T_66dd0_row2_col7 {
#   background-color: #e2650f;
#   color: #f1f1f1;
# }
# #T_66dd0_row2_col8 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_66dd0_row2_col9, #T_66dd0_row9_col7 {
#   background-color: #fff9c6;
#   color: #000000;
# }
# #T_66dd0_row2_col10, #T_66dd0_row4_col8 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# #T_66dd0_row3_col0, #T_66dd0_row3_col9, #T_66dd0_row3_col10, #T_66dd0_row4_col2, #T_66dd0_row5_col8, #T_66dd0_row6_col3, #T_66dd0_row7_col2, #T_66dd0_row10_col0, #T_66dd0_row10_col2, #T_66dd0_row10_col3, #T_66dd0_row12_col2, #T_66dd0_row12_col8 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_66dd0_row3_col2, #T_66dd0_row6_col0, #T_66dd0_row6_col7, #T_66dd0_row7_col4, #T_66dd0_row8_col0, #T_66dd0_row11_col0, #T_66dd0_row14_col0 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_66dd0_row3_col4 {
#   background-color: #fb9326;
#   color: #000000;
# }
# #T_66dd0_row3_col5, #T_66dd0_row15_col10 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_66dd0_row3_col6, #T_66dd0_row14_col1 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_66dd0_row4_col0, #T_66dd0_row9_col8 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_66dd0_row4_col4 {
#   background-color: #ed7316;
#   color: #f1f1f1;
# }
# #T_66dd0_row4_col6 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_66dd0_row4_col7 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_66dd0_row5_col7, #T_66dd0_row13_col0 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_66dd0_row6_col10, #T_66dd0_row7_col0, #T_66dd0_row8_col8, #T_66dd0_row8_col10, #T_66dd0_row10_col8, #T_66dd0_row12_col9, #T_66dd0_row14_col8, #T_66dd0_row14_col10 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_66dd0_row8_col4 {
#   background-color: #fff8c1;
#   color: #000000;
# }
# #T_66dd0_row9_col0 {
#   background-color: #fee99e;
#   color: #000000;
# }
# #T_66dd0_row9_col3 {
#   background-color: #fff5b8;
#   color: #000000;
# }
# #T_66dd0_row9_col4 {
#   background-color: #feba46;
#   color: #000000;
# }
# #T_66dd0_row9_col6 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_66dd0_row11_col4 {
#   background-color: #fff1b0;
#   color: #000000;
# }
# #T_66dd0_row12_col0 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_66dd0_row13_col4 {
#   background-color: #fea937;
#   color: #000000;
# }
# #T_66dd0_row13_col6 {
#   background-color: #fff7bd;
#   color: #000000;
# }
# #T_66dd0_row13_col7 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_66dd0_row13_col8 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_66dd0_row15_col0 {
#   background-color: #ee7416;
#   color: #f1f1f1;
# }
# #T_66dd0_row15_col1 {
#   background-color: #fee799;
#   color: #000000;
# }
# #T_66dd0_row15_col3, #T_66dd0_row15_col9 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_66dd0_row15_col4 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_66dd0_level0_col0, #T_66dd0_level0_col1, #T_66dd0_level0_col2, #T_66dd0_level0_col3, #T_66dd0_level0_col4, #T_66dd0_level0_col5, #T_66dd0_level0_col6, #T_66dd0_level0_col7, #T_66dd0_level0_col8, #T_66dd0_level0_col9, #T_66dd0_level0_col10 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_66dd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66dd0_level0_col0" class="col_heading level0 col0" >Biel/Bienne</th>
#       <th id="T_66dd0_level0_col1" class="col_heading level0 col1" >Erlach</th>
#       <th id="T_66dd0_level0_col2" class="col_heading level0 col2" >Gals</th>
#       <th id="T_66dd0_level0_col3" class="col_heading level0 col3" >Le Landeron</th>
#       <th id="T_66dd0_level0_col4" class="col_heading level0 col4" >Ligerz</th>
#       <th id="T_66dd0_level0_col5" class="col_heading level0 col5" >Lüscherz</th>
#       <th id="T_66dd0_level0_col6" class="col_heading level0 col6" >Nidau</th>
#       <th id="T_66dd0_level0_col7" class="col_heading level0 col7" >Vinelz</th>
#       <th id="T_66dd0_level0_col8" class="col_heading level0 col8" >Bielersee</th>
#       <th id="T_66dd0_level0_col9" class="col_heading level0 col9" >Aare-Erhebungsgebiet</th>
#       <th id="T_66dd0_level0_col10" class="col_heading level0 col10" >Alle Erhebungsgebiete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66dd0_level0_row0" class="row_heading level0 row0" >Expandiertes Polystyrol</th>
#       <td id="T_66dd0_row0_col0" class="data row0 col0" >19,0</td>
#       <td id="T_66dd0_row0_col1" class="data row0 col1" >2,0</td>
#       <td id="T_66dd0_row0_col2" class="data row0 col2" >0,0</td>
#       <td id="T_66dd0_row0_col3" class="data row0 col3" >8,0</td>
#       <td id="T_66dd0_row0_col4" class="data row0 col4" >6,0</td>
#       <t

# %% [markdown]
# ```{glue:figure} bielersee_most_common_heat_map
# ---
# name: 'bielersee_most_common_heat_map'
# ---
# ` `
# ```

# %% [markdown]
# {numref}`Abbildung %s: <bielersee_most_common_heat_map>` {glue:text}`mc_heat_map_caption`

# %% [markdown]
# ### Die am häufigsten gefundenen Objekte im monatlichen Durchschnitt

# %%
# collect the survey results of the most common objects
agg_pcs_quantity = {unit_label:"sum", "quantity":"sum"}
agg_pcs_median = {unit_label:"median", "quantity":"sum"}

# collect the code data for the most common codes
m_common_m = fd[(fd.code.isin(fdx.most_common.index))].groupby(["loc_date","date","code", "groupname"], as_index=False).agg(agg_pcs_quantity)

# get the total per code and set the order of the
# index by quantity
m_common_m.set_index("date", inplace=True)

# set the order of the chart, group the codes by groupname columns
an_order = m_common_m.groupby(["code","groupname"], as_index=False).quantity.sum().sort_values(by="groupname")["code"].values

# collect the monthly results for each code
# into a dict, key = description
mgr = {}
for a_group in an_order:
    # resample by month
    a_cell = m_common_m[(m_common_m.code==a_group)][unit_label].resample("M").mean().fillna(0)
    this_group = {a_group:a_cell}
    mgr.update(this_group)

# make df and collect the abbreviated month name
# set that to index
by_month = pd.DataFrame.from_dict(mgr)
by_month["month"] = by_month.index.map(lambda x: get_month_names('abbreviated', locale=date_lang)[x.month])
by_month.set_index('month', drop=True, inplace=True)

# transpose to get months on the columns
mcdm = by_month.T
mcdm = mcdm.astype("int")
mcdm["Objekt"] = mcdm.index.map(lambda x: fdx.dMap.loc[x])
mcdm.set_index("Objekt", drop=True, inplace=True)
mcdm.index.name = None
mcdm.columns.name = None
mcdm = mcdm.round(1)

monthly_data_caption = f'{this_feature["name"]}, monatliche Durchschnittsergebnisse p/100 m'

# pdf components
mc_monthly_title = Paragraph("Die am häufigsten gefundenen Objekte im monatlichen Durchschnitt", featuredata.subsection_title)
monthly_results = featuredata.aStyledTable(mcdm.reset_index(), vertical_header=True, colWidths=[2.3*inch] + [.38*inch]*len(mcdm.columns[1:]))
monthly_heat_map_gradient = featuredata.colorGradientTable(mcdm)
monthly_results.setStyle(monthly_heat_map_gradient)
monthly_caption = Paragraph(monthly_data_caption, featuredata.caption_style)

new_components = [
    mc_monthly_title, 
    featuredata.small_space,
    monthly_results,
    featuredata.smallest_space,
    monthly_caption,
    PageBreak()
]

pdfcomponents = featuredata.addToDoc(new_components, pdfcomponents)

mcdm.index.name = None
mcdm.columns.name = None

aformatter = {x: '{:.1f}' for x in mcdm.columns}

mcdm = mcdm.style.format(aformatter).set_table_styles(table_css_styles).background_gradient(axis=None, vmin=mcdm.min().min(), vmax=mcdm.max().max(), cmap="YlOrBr")

glue("bielersee_monthly_results", mcdm, display=False)
# Out:
# <style type="text/css">
# #T_db607 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_db607 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_db607 tr {
#   font-size: 14px;
# }
# #T_db607 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_db607_row0_col0, #T_db607_row2_col11, #T_db607_row3_col8, #T_db607_row10_col9, #T_db607_row14_col7, #T_db607_row15_col3, #T_db607_row15_col7 {
#   background-color: #fffacd;
#   color: #000000;
# }
# #T_db607_row0_col1, #T_db607_row0_col10, #T_db607_row1_col6, #T_db607_row2_col7, #T_db607_row8_col2, #T_db607_row15_col4, #T_db607_row15_col6, #T_db607_row15_col8 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_db607_row0_col2, #T_db607_row0_col7, #T_db607_row5_col0, #T_db607_row5_col1, #T_db607_row5_col2, #T_db607_row5_col7, #T_db607_row5_col10, #T_db607_row5_col11, #T_db607_row6_col0, #T_db607_row6_col7, #T_db607_row10_col6, #T_db607_row11_col0, #T_db607_row11_col3, #T_db607_row15_col0, #T_db607_row15_col1, #T_db607_row15_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_db607_row0_col3, #T_db607_row0_col11, #T_db607_row1_col3, #T_db607_row1_col4, #T_db607_row4_col2, #T_db607_row4_col11, #T_db607_row6_col11 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_db607_row0_col4, #T_db607_row0_col8, #T_db607_row2_col0, #T_db607_row2_col8, #T_db607_row6_col4, #T_db607_row7_col10, #T_db607_row7_col11, #T_db607_row8_col4, #T_db607_row8_col7, #T_db607_row9_col8, #T_db607_row10_col2, #T_db607_row11_col5, #T_db607_row13_col4, #T_db607_row13_col11, #T_db607_row14_col8 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_db607_row0_col5, #T_db607_row2_col3, #T_db607_row4_col5, #T_db607_row4_col9, #T_db607_row8_col5 {
#   background-color: #fffacb;
#   color: #000000;
# }
# #T_db607_row0_col6, #T_db607_row1_col7, #T_db607_row4_col3, #T_db607_row4_col7, #T_db607_row4_col8, #T_db607_row6_col1, #T_db607_row7_col2, #T_db607_row10_col7, #T_db607_row10_col10, #T_db607_row11_col7, #T_db607_row13_col3, #T_db607_row13_col8 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_db607_row0_col9, #T_db607_row1_col0, #T_db607_row1_col1, #T_db607_row1_col10, #T_db607_row2_col2, #T_db607_row4_col6, #T_db607_row7_col5, #T_db607_row11_col10, #T_db607_row13_col7, #T_db607_row14_col6 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_db607_row1_col2, #T_db607_row1_col9, #T_db607_row5_col8, #T_db607_row6_col8, #T_db607_row11_col1, #T_db607_row11_col2, #T_db607_row11_col6, #T_db607_row11_col8, #T_db607_row11_col9, #T_db607_row11_col11, #T_db607_row13_col9 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_db607_row1_col5, #T_db607_row2_col10, #T_db607_row6_col2, #T_db607_row10_col3, #T_db607_row13_col6, #T_db607_row13_col10 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_db607_row1_col8, #T_db607_row2_col1, #T_db607_row4_col1, #T_db607_row6_col5, #T_db607_row6_col9, #T_db607_row7_col3, #T_db607_row7_col9, #T_db607_row8_col8, #T_db607_row10_col1, #T_db607_row13_col2 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_db607_row1_col11, #T_db607_row2_col9, #T_db607_row4_col4, #T_db607_row5_col3, #T_db607_row5_col6, #T_db607_row6_col6, #T_db607_row7_col4, #T_db607_row7_col6, #T_db607_row7_col7, #T_db607_row7_col8, #T_db607_row8_col11, #T_db607_row10_col0, #T_db607_row10_col8, #T_db607_row10_col11, #T_db607_row11_col4 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_db607_row2_col4 {
#   background-color: #fff5b8;
#   color: #000000;
# }
# #T_db607_row2_col5 {
#   background-color: #fd9728;
#   color: #000000;
# }
# #T_db607_row2_col6 {
#   background-color: #fee08a;
#   color: #000000;
# }
# #T_db607_row3_col0 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_db607_row3_col1, #T_db607_row9_col1 {
#   background-color: #fee18c;
#   color: #000000;
# }
# #T_db607_row3_col2, #T_db607_row5_col5, #T_db607_row8_col10, #T_db607_row9_col9 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_db607_row3_col3, #T_db607_row3_col7 {
#   background-color: #fff1ae;
#   color: #000000;
# }
# #T_db607_row3_col4, #T_db607_row12_col7, #T_db607_row13_col5 {
#   background-color: #feeba2;
#   color: #000000;
# }
# #T_db607_row3_col5 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_db607_row3_col6, #T_db607_row3_col11, #T_db607_row8_col3, #T_db607_row8_col6 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_db607_row3_col9, #T_db607_row6_col3, #T_db607_row13_col0 {
#   background-color: #fff7bc;
#   color: #000000;
# }
# #T_db607_row3_col10, #T_db607_row4_col10 {
#   background-color: #fee799;
#   color: #000000;
# }
# #T_db607_row4_col0, #T_db607_row9_col6, #T_db607_row10_col5 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_db607_row5_col4 {
#   background-color: #fee99e;
#   color: #000000;
# }
# #T_db607_row5_col9, #T_db607_row8_col1, #T_db607_row9_col3, #T_db607_row9_col11 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_db607_row6_col10 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_db607_row7_col0 {
#   background-color: #fecd63;
#   color: #000000;
# }
# #T_db607_row7_col1, #T_db607_row12_col8, #T_db607_row15_col9 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_db607_row8_col0 {
#   background-color: #fed87a;
#   color: #000000;
# }
# #T_db607_row8_col9 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_db607_row9_col0 {
#   background-color: #a83b03;
#   color: #f1f1f1;
# }
# #T_db607_row9_col2, #T_db607_row9_col10 {
#   background-color: #ffefaa;
#   color: #000000;
# }
# #T_db607_row9_col4 {
#   background-color: #fec14c;
#   color: #000000;
# }
# #T_db607_row9_col5 {
#   background-color: #f27f1b;
#   color: #f1f1f1;
# }
# #T_db607_row9_col7, #T_db607_row15_col11 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_db607_row10_col4 {
#   background-color: #fff6ba;
#   color: #000000;
# }
# #T_db607_row12_col0 {
#   background-color: #ac3d03;
#   color: #f1f1f1;
# }
# #T_db607_row12_col1, #T_db607_row14_col4 {
#   background-color: #feab39;
#   color: #000000;
# }
# #T_db607_row12_col2 {
#   background-color: #feb945;
#   color: #000000;
# }
# #T_db607_row12_col3, #T_db607_row12_col11 {
#   background-color: #febb47;
#   color: #000000;
# }
# #T_db607_row12_col4 {
#   background-color: #ea6e13;
#   color: #f1f1f1;
# }
# #T_db607_row12_col5 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_db607_row12_col6 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_db607_row12_col9 {
#   background-color: #f88a21;
#   color: #f1f1f1;
# }
# #T_db607_row12_col10 {
#   background-color: #cc4c02;
#   color: #f1f1f1;
# }
# #T_db607_row13_col1 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# #T_db607_row14_col0 {
#   background-color: #e56910;
#   color: #f1f1f1;
# }
# #T_db607_row14_col1 {
#   background-color: #fec24d;
#   color: #000000;
# }
# #T_db607_row14_col2 {
#   background-color: #fea030;
#   color: #000000;
# }
# #T_db607_row14_col3 {
#   background-color: #fee89d;
#   color: #000000;
# }
# #T_db607_row14_col5 {
#   background-color: #fe9b2b;
#   color: #000000;
# }
# #T_db607_row14_col9 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_db607_row14_col10 {
#   background-color: #a43904;
#   color: #f1f1f1;
# }
# #T_db607_row14_col11 {
#   background-color: #fed069;
#   color: #000000;
# }
# #T_db607_row15_col5 {
#   background-color: #fec550;
#   color: #000000;
# }
# #T_db607_row15_col10 {
#   background-color: #fead3a;
#   color: #000000;
# }
# </style>
# <table id="T_db607">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db607_level0_col0" class="col_heading level0 col0" >Apr.</th>
#       <th id="T_db607_level0_col1" class="col_heading level0 col1" >Mai</th>
#       <th id="T_db607_level0_col2" class="col_heading level0 col2" >Juni</th>
#       <th id="T_db607_level0_col3" class="col_heading level0 col3" >Juli</th>
#       <th id="T_db607_level0_col4" class="col_heading level0 col4" >Aug.</th>
#       <th id="T_db607_level0_col5" class="col_heading level0 col5" >Sept.</th>
#       <th id="T_db607_level0_col6" class="col_heading level0 col6" >Okt.</th>
#       <th id="T_db607_level0_col7" class="col_heading level0 col7" >Nov.</th>
#       <th id="T_db607_level0_col8" class="col_heading level0 col8" >Dez.</th>
#       <th id="T_db607_level0_col9" class="col_heading level0 col9" >Jan.</th>
#       <th id="T_db607_level0_col10" class

# %% [markdown]
# ```{glue:figure} bielersee_monthly_results
# ---
# name: 'bielersee_monthly_results'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_monthly_results>` Bielersee, monatliche Durchschnittsergebnisse p/100 m.

# %% [markdown]
# ## Verwendungszweck der gefundenen Objekte
#
# Der Verwendungszweck basiert auf der Verwendung des Objekts, bevor es weggeworfen wurde, oder auf der Artikelbeschreibung, wenn die ursprüngliche Verwendung unbestimmt ist. Identifizierte Objekte werden einer der 260 vordefinierten Kategorien zugeordnet. Die Kategorien werden je nach Verwendung oder Artikelbeschreibung gruppiert.
#
# * Abwasser: Objekte, die aus Kläranlagen freigesetzt werden, sprich Objekte, die wahrscheinlich über die Toilette entsorgt werden
# * Mikroplastik (< 5 mm): fragmentierte Kunststoffe und Kunststoffharze aus der Vorproduktion
# * Infrastruktur: Artikel im Zusammenhang mit dem Bau und der Instandhaltung von Gebäuden, Strassen und der Wasser-/Stromversorgung
# * Essen und Trinken: alle Materialien, die mit dem Konsum von Essen und Trinken in Zusammenhang stehen
# * Landwirtschaft: Materialien z. B. für Mulch und Reihenabdeckungen, Gewächshäuser, Bodenbegasung, Ballenverpackungen. Einschliesslich Hartkunststoffe für landwirtschaftliche Zäune, Blumentöpfe usw.
# * Tabakwaren: hauptsächlich Zigarettenfilter, einschliesslich aller mit dem Rauchen verbundenen Materialien
# * Freizeit und Erholung: Objekte, die mit Sport und Freizeit zu tun haben, z. B. Angeln, Jagen, Wandern usw.
# * Verpackungen ausser Lebensmittel und Tabak: Verpackungsmaterial, das nicht lebensmittel- oder tabakbezogen ist
# * Plastikfragmente: Plastikteile unbestimmter Herkunft oder Verwendung
# * Persönliche Gegenstände: Accessoires, Hygieneartikel und Kleidung
#
# Im Anhang (Kapitel 3.6.3) befindet sich die vollständige Liste der identifizierten Objekte, einschliesslich Beschreibungen und Gruppenklassifizierung. Das Kapitel [16 Codegruppen](codegroups) beschreibt jede Codegruppe im Detail und bietet eine umfassende Liste aller Objekte in einer Gruppe.

# %%
# make pdf out put
cone_group_subtitle = Paragraph("Verwendungszweck der gefundenen Objekte", featuredata.section_title)

paragraph_one = [
    "Der Verwendungszweck basiert auf der Verwendung des Objekts, bevor es weggeworfen wurde, ",
    "oder auf der Artikelbeschreibung, wenn die ursprüngliche Verwendung unbestimmt ist. ",
    "Identifizierte Objekte werden einer der 260 vordefinierten Kategorien zugeordnet. ",
    "Die Kategorien werden je nach Verwendung oder Artikelbeschreibung gruppiert."
]

group_names_list = [
    "Abwasser: Objekte, die aus Kläranlagen freigesetzt werden, sprich Objekte, die wahrscheinlich über die Toilette entsorgt werden",
    "Mikroplastik (< 5 mm): fragmentierte Kunststoffe und Kunststoffharze aus der Vorproduktion",
    "Infrastruktur: Artikel im Zusammenhang mit dem Bau und der Instandhaltung von Gebäuden, Strassen und der Wasser-/Stromversorgung",
    "Essen und Trinken: alle Materialien, die mit dem Konsum von Essen und Trinken in Zusammenhang stehen",
    "Landwirtschaft: Materialien z. B. für Mulch und Reihenabdeckungen, Gewächshäuser, Bodenbegasung, Ballenverpackungen. Einschliesslich Hartkunststoffe für landwirtschaftliche Zäune, Blumentöpfe usw.",
    "Tabakwaren: hauptsächlich Zigarettenfilter, einschliesslich aller mit dem Rauchen verbundenen Materialien",
    "Freizeit und Erholung: Objekte, die mit Sport und Freizeit zu tun haben, z. B. Angeln, Jagen, Wandern usw.",
    "Verpackungen ausser Lebensmittel und Tabak: Verpackungsmaterial, das nicht lebensmittel- oder tabakbezogen ist",
    "Plastikfragmente: Plastikteile unbestimmter Herkunft oder Verwendung",
    "Persönliche Gegenstände: Accessoires, Hygieneartikel und Kleidung"
]

paragraph_three = [
    "Im Anhang (Kapitel 3.6.3) befindet sich die vollständige Liste der identifizierten Objekte, ",
    "einschliesslich Beschreibungen und Gruppenklassifizierung. ",
    "Das Kapitel [16 Codegruppen](codegroups) beschreibt jede Codegruppe im Detail und bietet eine ",
    "umfassende Liste aller Objekte in einer Gruppe."
]


# make paragraphs
code_group_para_one = ' '.join(paragraph_one)
code_group_para_three = ''.join(paragraph_three)

name_list = [ListItem(Paragraph(x, featuredata.p_style), bulletColor=HexColor("#000000")) for x in group_names_list]

cgroup_pone = Paragraph(code_group_para_one, featuredata.p_style)

cgroup_pthree = Paragraph(code_group_para_three, featuredata.p_style)
a_list_groups = ListFlowable(name_list, bulletType='bullet', start="square", bulletFontSize=6)

new_components = [
    cone_group_subtitle,
    featuredata.small_space,
    cgroup_pone,
    featuredata.small_space,
    a_list_groups,
    featuredata.small_space,
    cgroup_pthree
]

pdfcomponents = featuredata.addToDoc(new_components, pdfcomponents)

# %%
# the results are a callable for the components
components = fdx.componentCodeGroupResults()

# pivot that and reomve any hierarchal column index
pt_comp = components[["city", "groupname", '% of total' ]].pivot(columns="city", index="groupname")
pt_comp.columns = pt_comp.columns.get_level_values(1)

# the aggregated codegroup results from the feature
pt_feature = fdx.codegroup_summary["% of total"]
pt_comp[this_feature["name"]] = pt_feature

# the aggregated totals for the parent level
pt_parent = period_data.parentGroupTotals(parent=True, percent=True)
pt_comp[bassin_label] = pt_parent

# the aggregated totals for the period
pt_period = period_data.parentGroupTotals(parent=False, percent=True)
pt_comp[top] = pt_period

# caption
code_group_percent_caption = [
    'Verwendungszweck oder Beschreibung der identifizierten Objekte in % der ',
    f'Gesamtzahl nach Gemeinden im Erhebungsgebiet {this_feature["name"]}. '
    'Fragmentierte Objekte, die nicht eindeutig identifiziert werden können, ',
    'werden weiterhin nach ihrer Grösse klassifiziert.'
]

code_group_percent_caption = ''.join(code_group_percent_caption)

# format for data frame
pt_comp.index.name = None
pt_comp.columns.name = None
aformatter = {x: '{:.0%}' for x in pt_comp.columns}
ptd = pt_comp.style.format(aformatter).set_table_styles(table_css_styles).background_gradient(axis=None, vmin=pt_comp.min().min(), vmax=pt_comp.max().max(), cmap="YlOrBr")
ptd = ptd.applymap_index(featuredata.rotateText, axis=1)

# pdf and display output
code_group_percent_gradient = featuredata.colorGradientTable(pt_comp.apply(lambda x: x*100).astype(int))
pt_comp = pt_comp.applymap(lambda x: '{:.0%}'.format(x))

code_group_percent = featuredata.aStyledTable(pt_comp.reset_index(),vertical_header=True,colWidths=[2.3*inch] + [None]*len(pt_comp.columns))
code_group_percent.setStyle(code_group_percent_gradient)
cgpercent_caption = Paragraph(code_group_percent_caption, featuredata.caption_style)

glue("bielersee_codegroup_percent_caption", code_group_percent_caption, display=False)
glue("bielersee_codegroup_percent", ptd, display=False)
# Out:
# 'Verwendungszweck oder Beschreibung der identifizierten Objekte in % der Gesamtzahl nach Gemeinden im Erhebungsgebiet Bielersee. Fragmentierte Objekte, die nicht eindeutig identifiziert werden können, werden weiterhin nach ihrer Grösse klassifiziert.'
# <style type="text/css">
# #T_9be5a tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_9be5a tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_9be5a tr {
#   font-size: 14px;
# }
# #T_9be5a th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_9be5a_row0_col0, #T_9be5a_row0_col4, #T_9be5a_row2_col6, #T_9be5a_row4_col2, #T_9be5a_row5_col5, #T_9be5a_row6_col0, #T_9be5a_row6_col3, #T_9be5a_row9_col2, #T_9be5a_row9_col5, #T_9be5a_row10_col2, #T_9be5a_row10_col5, #T_9be5a_row10_col7 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_9be5a_row0_col1, #T_9be5a_row0_col2, #T_9be5a_row2_col8, #T_9be5a_row3_col3, #T_9be5a_row4_col8, #T_9be5a_row5_col10 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_9be5a_row0_col3, #T_9be5a_row0_col5, #T_9be5a_row0_col6, #T_9be5a_row3_col2, #T_9be5a_row4_col1, #T_9be5a_row5_col3, #T_9be5a_row5_col4, #T_9be5a_row6_col6, #T_9be5a_row8_col6, #T_9be5a_row10_col1, #T_9be5a_row10_col3, #T_9be5a_row10_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_9be5a_row0_col7, #T_9be5a_row0_col8, #T_9be5a_row3_col4, #T_9be5a_row6_col8, #T_9be5a_row6_col9, #T_9be5a_row6_col10, #T_9be5a_row8_col7 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_9be5a_row0_col9, #T_9be5a_row2_col10, #T_9be5a_row3_col1, #T_9be5a_row6_col2, #T_9be5a_row6_col4, #T_9be5a_row6_col7 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_9be5a_row0_col10, #T_9be5a_row2_col4, #T_9be5a_row2_col9, #T_9be5a_row5_col0, #T_9be5a_row5_col7, #T_9be5a_row5_col8, #T_9be5a_row5_col9, #T_9be5a_row9_col10 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_9be5a_row1_col0, #T_9be5a_row3_col10 {
#   background-color: #fa8f24;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col1, #T_9be5a_row4_col6 {
#   background-color: #fea332;
#   color: #000000;
# }
# #T_9be5a_row1_col2 {
#   background-color: #a13804;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col3, #T_9be5a_row7_col4, #T_9be5a_row8_col3 {
#   background-color: #ed7215;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col4, #T_9be5a_row8_col0 {
#   background-color: #c64902;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col5 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col6 {
#   background-color: #7e2c05;
#   color: #f1f1f1;
# }
# #T_9be5a_row1_col7, #T_9be5a_row7_col3, #T_9be5a_row9_col3 {
#   background-color: #feae3b;
#   color: #000000;
# }
# #T_9be5a_row1_col8, #T_9be5a_row1_col9, #T_9be5a_row1_col10, #T_9be5a_row7_col5, #T_9be5a_row8_col8 {
#   background-color: #f5851f;
#   color: #f1f1f1;
# }
# #T_9be5a_row2_col0, #T_9be5a_row2_col7, #T_9be5a_row6_col5, #T_9be5a_row9_col7 {
#   background-color: #fee08a;
#   color: #000000;
# }
# #T_9be5a_row2_col1, #T_9be5a_row4_col9, #T_9be5a_row9_col0, #T_9be5a_row9_col8, #T_9be5a_row9_col9 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_9be5a_row2_col2, #T_9be5a_row2_col3, #T_9be5a_row2_col5, #T_9be5a_row3_col6, #T_9be5a_row4_col0, #T_9be5a_row4_col5, #T_9be5a_row4_col10, #T_9be5a_row5_col6, #T_9be5a_row6_col1, #T_9be5a_row8_col5, #T_9be5a_row9_col1 {
#   background-color: #ffefaa;
#   color: #000000;
# }
# #T_9be5a_row3_col0, #T_9be5a_row3_col7, #T_9be5a_row3_col8, #T_9be5a_row9_col4 {
#   background-color: #fed16b;
#   color: #000000;
# }
# #T_9be5a_row3_col5, #T_9be5a_row3_col9, #T_9be5a_row4_col3, #T_9be5a_row4_col7, #T_9be5a_row8_col4, #T_9be5a_row9_col6 {
#   background-color: #fec24d;
#   color: #000000;
# }
# #T_9be5a_row4_col4, #T_9be5a_row7_col9, #T_9be5a_row7_col10 {
#   background-color: #feb744;
#   color: #000000;
# }
# #T_9be5a_row5_col1, #T_9be5a_row10_col0, #T_9be5a_row10_col4, #T_9be5a_row10_col8, #T_9be5a_row10_col9, #T_9be5a_row10_col10 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_9be5a_row5_col2, #T_9be5a_row7_col0 {
#   background-color: #fec95b;
#   color: #000000;
# }
# #T_9be5a_row7_col1, #T_9be5a_row7_col7 {
#   background-color: #ae3e03;
#   color: #f1f1f1;
# }
# #T_9be5a_row7_col2 {
#   background-color: #de610c;
#   color: #f1f1f1;
# }
# #T_9be5a_row7_col6, #T_9be5a_row8_col1 {
#   background-color: #cf5004;
#   color: #f1f1f1;
# }
# #T_9be5a_row7_col8, #T_9be5a_row8_col10 {
#   background-color: #fe9829;
#   color: #000000;
# }
# #T_9be5a_row8_col2 {
#   background-color: #fed87a;
#   color: #000000;
# }
# #T_9be5a_row8_col9 {
#   background-color: #f17c1a;
#   color: #f1f1f1;
# }
# #T_9be5a_level0_col0, #T_9be5a_level0_col1, #T_9be5a_level0_col2, #T_9be5a_level0_col3, #T_9be5a_level0_col4, #T_9be5a_level0_col5, #T_9be5a_level0_col6, #T_9be5a_level0_col7, #T_9be5a_level0_col8, #T_9be5a_level0_col9, #T_9be5a_level0_col10 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_9be5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9be5a_level0_col0" class="col_heading level0 col0" >Biel/Bienne</th>
#       <th id="T_9be5a_level0_col1" class="col_heading level0 col1" >Erlach</th>
#       <th id="T_9be5a_level0_col2" class="col_heading level0 col2" >Gals</th>
#       <th id="T_9be5a_level0_col3" class="col_heading level0 col3" >Le Landeron</th>
#       <th id="T_9be5a_level0_col4" class="col_heading level0 col4" >Ligerz</th>
#       <th id="T_9be5a_level0_col5" class="col_heading level0 col5" >Lüscherz</th>
#       <th id="T_9be5a_level0_col6" class="col_heading level0 col6" >Nidau</th>
#       <th id="T_9be5a_level0_col7" class="col_heading level0 col7" >Vinelz</th>
#       <th id="T_9be5a_level0_col8" class="col_heading level0 col8" >Bielersee</th>
#       <th id="T_9be5a_level0_col9" class="col_heading level0 col9" >Aare-Erhebungsgebiet</th>
#       <th id="T_9be5a_level0_col10" class="col_heading level0 col10" >Alle Erhebungsgebiete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9be5a_level0_row0" class="row_heading level0 row0" >Abwasser</th>
#       <td id="T_9be5a_row0_col0" class="data row0 col0" >2%</td>
#       <td id="T_9be5a_row0_col1" class="data row0 col1" >8%</td>
#       <td id="T_9be5a_row0_col2" class="data row0 col2" >8%</td>
#       <td id="T_9be5a_row0_col3" class="data row0 col3" >0%</td>
#       <td id="T_9be5a_row0_col4" class="data row0 col4" >2%</td>
#       <td id="T_9be5a_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_9be5a_row0_col6" class="data row0 col6" >0%</td>
#       <td id="T_9be5a_row0_col7" class="data row0 col7" >3%</td>
#       <td id="T_9be5a_row0_col8" class="data row0 col8" >3%</td>
#       <td id="T_9be5a_row0_col9" class="data row0 col9" >4%</td>
#       <td id="T_9be5a_row0_col10" class="data row0 col10" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_9be5a_level0_row1" class="row_heading level0 row1" >Essen und Trinken</th>
#       <td id="T_9be5a_row1_col0" class="data row1 col0" >18%</td>
#       <td id="T_9be5a_row1_col1" class="data row1 col1" >16%</td>
#       <td id="T_9be5a_row1_col2" class="data row1 col2" >29%</td>
#       <td id="T_9be5a_row1_col3" class="data row1 col3" >21%</td>
#       <td id="T_9be5a_row1_col4" class="data row1 col4" >26%</td>
#       <td id="T_9be5a_row1_col5" class="data row1 col5" >34%</td>
#       <td id="T_9be5a_row1_col6" class="data row1 col6" >32%</td>
#       <td id="T_9be5a_row1_col7" class="data row1 col7" >15%</td>
#       <td id="T_9be5a_row1_col8" class="data row1 col8" >19%</td>
#       <td id="T_9be5a_row1_col9" class="data row1 col9" >19%</td>
#       <td id="T_9be5a_row1_col10" class="data row1 col10" >19%</td>
#     </tr>
#     <tr>
#       <th id="T_9be5a_level0_row2" class="row_heading level0 row2" >Freizeit und Erholung</th>
#       <td id="T_9be5a_row2_col0" class="data row2 col0" >9%</td>
#       <td id="T_9be5a_row2_col1" class="data row2 col1" >7%</td>
#       <td id="T_9be5a_row2_col2" class="data row2 col2" >6%</td>
#       <td id="T_9be5a_row2_col3" class="data row2 col3" >6%</td>
#       <td id="T_9be5a_row2_col4" class="data row2 col4" >5%</td>
#       <td id="T_9be5a_row2_col5" class="data row2 col5" >6%</td>
#       <td id="T_9be5a_row2_col6" class="data row2 col6" >2%</td>
#       <td id="T_9be5a_row2_col7" class="data row2 col7" >9%</td>
#       <td id="T_9be5a_row2_col8" class="data row2 col8" >8%</td>
#       <td id="T_9be5a_row2_col9" class="data row2 col9" >5%</td>
#       <td id="T_9be5a_row2_col10" class="data

# %% [markdown]
# ```{glue:figure} bielersee_codegroup_percent
# ---
# name: 'bielersee_codegroup_percent'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_codegroup_percent>`  {glue:text}`bielersee_codegroup_percent_caption`

# %%
# pivot that
grouppcs_comp = components[["city", "groupname", unit_label ]].pivot(columns="city", index="groupname")

# quash the hierarchal column index
grouppcs_comp.columns = grouppcs_comp.columns.get_level_values(1)

# the aggregated codegroup results from the feature
pt_feature = fdx.codegroup_summary[unit_label]
grouppcs_comp[this_feature["name"]] = pt_feature

# the aggregated totals for the parent level
pt_parent = period_data.parentGroupTotals(parent=True, percent=False)
grouppcs_comp[bassin_label] = pt_parent

# the aggregated totals for the period
pt_period = period_data.parentGroupTotals(parent=False, percent=False)
grouppcs_comp[top] = pt_period

# color gradient of restults
code_group_pcsm_gradient = featuredata.colorGradientTable(grouppcs_comp)

aformatter = {x: '{:.1f}' for x in grouppcs_comp.columns}
grouppcs_comp.index.name = None
grouppcs_comp.columns.name = None

# pdf and display output
code_group_pcsm_caption = [
    f'Verwendungszweck der gefundenen Objekte Median {unit_label} am ',
    f'{this_feature["name"]}. Fragmentierte Objekte, die nicht eindeutig ',
    'identifiziert werden können, werden weiterhin nach ihrer Grösse klassifiziert.'
]
code_group_pcsm_caption = ''.join(code_group_pcsm_caption)
cgpcs_caption = Paragraph(code_group_pcsm_caption, featuredata.caption_style)

code_group_pcsm = featuredata.aStyledTable(grouppcs_comp.reset_index(),vertical_header=True, colWidths=[2.3*inch] + [None]*len(grouppcs_comp.columns[1:]))
code_group_pcsm.setStyle(code_group_pcsm_gradient)

cgp = grouppcs_comp.style.format(aformatter).set_table_styles(table_css_styles).background_gradient(axis=None, vmin=grouppcs_comp.min().min(), vmax=grouppcs_comp.max().max(), cmap="YlOrBr")
cgp= cgp.applymap_index(featuredata.rotateText, axis=1)


glue("bielersee_codegroup_pcsm_caption", code_group_pcsm_caption, display=False)

glue("bielersee_codegroup_pcsm", cgp, display=False)
# Out:
# 'Verwendungszweck der gefundenen Objekte Median p/100 m am Bielersee. Fragmentierte Objekte, die nicht eindeutig identifiziert werden können, werden weiterhin nach ihrer Grösse klassifiziert.'
# <style type="text/css">
# #T_95a7b tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_95a7b tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_95a7b tr {
#   font-size: 14px;
# }
# #T_95a7b th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_95a7b_row0_col0, #T_95a7b_row8_col7 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_95a7b_row0_col1, #T_95a7b_row7_col5, #T_95a7b_row8_col2 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_95a7b_row0_col2, #T_95a7b_row0_col7, #T_95a7b_row3_col3, #T_95a7b_row6_col0 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_95a7b_row0_col3, #T_95a7b_row0_col5, #T_95a7b_row0_col6, #T_95a7b_row3_col2, #T_95a7b_row4_col1, #T_95a7b_row5_col3, #T_95a7b_row5_col4, #T_95a7b_row5_col5, #T_95a7b_row6_col6, #T_95a7b_row8_col6, #T_95a7b_row10_col1, #T_95a7b_row10_col3, #T_95a7b_row10_col5, #T_95a7b_row10_col6, #T_95a7b_row10_col9, #T_95a7b_row10_col10 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_95a7b_row0_col4, #T_95a7b_row3_col10, #T_95a7b_row4_col8, #T_95a7b_row8_col8, #T_95a7b_row9_col8 {
#   background-color: #fffaca;
#   color: #000000;
# }
# #T_95a7b_row0_col8, #T_95a7b_row2_col2, #T_95a7b_row6_col7, #T_95a7b_row6_col8, #T_95a7b_row9_col10 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_95a7b_row0_col9, #T_95a7b_row0_col10, #T_95a7b_row6_col3, #T_95a7b_row10_col0, #T_95a7b_row10_col2, #T_95a7b_row10_col8 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_95a7b_row1_col0 {
#   background-color: #febe4a;
#   color: #000000;
# }
# #T_95a7b_row1_col1 {
#   background-color: #fff7bd;
#   color: #000000;
# }
# #T_95a7b_row1_col2 {
#   background-color: #fff3b2;
#   color: #000000;
# }
# #T_95a7b_row1_col3, #T_95a7b_row8_col3 {
#   background-color: #fff7bc;
#   color: #000000;
# }
# #T_95a7b_row1_col4 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_95a7b_row1_col5, #T_95a7b_row1_col9, #T_95a7b_row3_col4, #T_95a7b_row9_col0 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_95a7b_row1_col6 {
#   background-color: #fecd63;
#   color: #000000;
# }
# #T_95a7b_row1_col7 {
#   background-color: #fee08a;
#   color: #000000;
# }
# #T_95a7b_row1_col8 {
#   background-color: #fee493;
#   color: #000000;
# }
# #T_95a7b_row1_col10 {
#   background-color: #fff2b1;
#   color: #000000;
# }
# #T_95a7b_row2_col0, #T_95a7b_row9_col6 {
#   background-color: #fff6b9;
#   color: #000000;
# }
# #T_95a7b_row2_col1 {
#   background-color: #fffbd3;
#   color: #000000;
# }
# #T_95a7b_row2_col3, #T_95a7b_row2_col5, #T_95a7b_row3_col1, #T_95a7b_row9_col9 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_95a7b_row2_col4, #T_95a7b_row4_col7 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_95a7b_row2_col6, #T_95a7b_row6_col9 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_95a7b_row2_col7, #T_95a7b_row7_col10 {
#   background-color: #fffacd;
#   color: #000000;
# }
# #T_95a7b_row2_col8, #T_95a7b_row3_col9, #T_95a7b_row8_col9 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_95a7b_row2_col9, #T_95a7b_row2_col10, #T_95a7b_row4_col9, #T_95a7b_row6_col10, #T_95a7b_row10_col4 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_95a7b_row3_col0 {
#   background-color: #fedf88;
#   color: #000000;
# }
# #T_95a7b_row3_col5, #T_95a7b_row4_col5, #T_95a7b_row6_col2, #T_95a7b_row6_col5, #T_95a7b_row8_col5 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_95a7b_row3_col6, #T_95a7b_row5_col2, #T_95a7b_row5_col6 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# #T_95a7b_row3_col7 {
#   background-color: #fff5b8;
#   color: #000000;
# }
# #T_95a7b_row3_col8 {
#   background-color: #fff8c4;
#   color: #000000;
# }
# #T_95a7b_row4_col0 {
#   background-color: #fff8c1;
#   color: #000000;
# }
# #T_95a7b_row4_col2, #T_95a7b_row5_col1, #T_95a7b_row9_col2, #T_95a7b_row9_col5 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_95a7b_row4_col3, #T_95a7b_row7_col9 {
#   background-color: #fffacb;
#   color: #000000;
# }
# #T_95a7b_row4_col4 {
#   background-color: #fa8f24;
#   color: #f1f1f1;
# }
# #T_95a7b_row4_col6 {
#   background-color: #fff0ad;
#   color: #000000;
# }
# #T_95a7b_row4_col10, #T_95a7b_row10_col7 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_95a7b_row5_col0 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_95a7b_row5_col7, #T_95a7b_row7_col3, #T_95a7b_row9_col3 {
#   background-color: #fff9c7;
#   color: #000000;
# }
# #T_95a7b_row5_col8, #T_95a7b_row6_col1, #T_95a7b_row9_col1 {
#   background-color: #fffcd4;
#   color: #000000;
# }
# #T_95a7b_row5_col9, #T_95a7b_row5_col10 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_95a7b_row6_col4 {
#   background-color: #fff1b0;
#   color: #000000;
# }
# #T_95a7b_row7_col0 {
#   background-color: #fee99e;
#   color: #000000;
# }
# #T_95a7b_row7_col1 {
#   background-color: #feeaa0;
#   color: #000000;
# }
# #T_95a7b_row7_col2 {
#   background-color: #fff7be;
#   color: #000000;
# }
# #T_95a7b_row7_col4 {
#   background-color: #b03f03;
#   color: #f1f1f1;
# }
# #T_95a7b_row7_col6 {
#   background-color: #fede86;
#   color: #000000;
# }
# #T_95a7b_row7_col7 {
#   background-color: #f88b22;
#   color: #f1f1f1;
# }
# #T_95a7b_row7_col8 {
#   background-color: #fee79a;
#   color: #000000;
# }
# #T_95a7b_row8_col0 {
#   background-color: #f07818;
#   color: #f1f1f1;
# }
# #T_95a7b_row8_col1 {
#   background-color: #ffeea8;
#   color: #000000;
# }
# #T_95a7b_row8_col4 {
#   background-color: #fd9728;
#   color: #000000;
# }
# #T_95a7b_row8_col10 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_95a7b_row9_col4 {
#   background-color: #feb340;
#   color: #000000;
# }
# #T_95a7b_row9_col7 {
#   background-color: #ffface;
#   color: #000000;
# }
# #T_95a7b_level0_col0, #T_95a7b_level0_col1, #T_95a7b_level0_col2, #T_95a7b_level0_col3, #T_95a7b_level0_col4, #T_95a7b_level0_col5, #T_95a7b_level0_col6, #T_95a7b_level0_col7, #T_95a7b_level0_col8, #T_95a7b_level0_col9, #T_95a7b_level0_col10 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_95a7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95a7b_level0_col0" class="col_heading level0 col0" >Biel/Bienne</th>
#       <th id="T_95a7b_level0_col1" class="col_heading level0 col1" >Erlach</th>
#       <th id="T_95a7b_level0_col2" class="col_heading level0 col2" >Gals</th>
#       <th id="T_95a7b_level0_col3" class="col_heading level0 col3" >Le Landeron</th>
#       <th id="T_95a7b_level0_col4" class="col_heading level0 col4" >Ligerz</th>
#       <th id="T_95a7b_level0_col5" class="col_heading level0 col5" >Lüscherz</th>
#       <th id="T_95a7b_level0_col6" class="col_heading level0 col6" >Nidau</th>
#       <th id="T_95a7b_level0_col7" class="col_heading level0 col7" >Vinelz</th>
#       <th id="T_95a7b_level0_col8" class="col_heading level0 col8" >Bielersee</th>
#       <th id="T_95a7b_level0_col9" class="col_heading level0 col9" >Aare-Erhebungsgebiet</th>
#       <th id="T_95a7b_level0_col10" class="col_heading level0 col10" >Alle Erhebungsgebiete</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95a7b_level0_row0" class="row_heading level0 row0" >Abwasser</th>
#       <td id="T_95a7b_row0_col0" class="data row0 col0" >9.5</td>
#       <td id="T_95a7b_row0_col1" class="data row0 col1" >14.0</td>
#       <td id="T_95a7b_row0_col2" class="data row0 col2" >11.0</td>
#       <td id="T_95a7b_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_95a7b_row0_col4" class="data row0 col4" >19.5</td>
#       <td id="T_95a7b_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_95a7b_row0_col6" class="data row0 col6" >0.0</td>
#       <td id="T_95a7b_row0_col7" class="data row0 col7" >11.0</td>
#       <td id="T_95a7b_row0_col8" class="data row0 col8" >9.0</td>
#       <td id="T_95a7b_row0_col9" class="data row0 col9" >3.0</td>
#       <td id="T_95a7b_row0_col10" class="data row0 col10" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_95a7b_level0_row1" class="row_heading level0 row1" >Essen und Trinken</th>
#       <td id="T_95a7b_row1_col0" class="data row1 col0" >93.0</td>
#       <td id="T_95a7b_row1_col1" class="data row1 col1" >29.0</td>
#       <td id="T_95a7b_row1_col2" class="data row1 col2" >36.5</td>
#       <td id="T_95a7b_row1_col3" class="data row1 col3" >30.0</td>

# %% [markdown]
# ```{glue:figure} bielersee_codegroup_pcsm
# ---
# name: 'bielersee_codegroup_pcsm'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_codegroup_pcsm>` {glue:text}`bielersee_codegroup_pcsm_caption`

# %% [markdown]
# ## Anhang
#
# ### Schaumstoffe und Kunststoffe nach Grösse
#
# Die folgende Tabelle enthält die Komponenten «Gfoam» und «Gfrag», die für die Analyse gruppiert wurden. Objekte, die als Schaumstoffe gekennzeichnet sind, werden als Gfoam gruppiert und umfassen alle geschäumten Polystyrol-Kunststoffe > 0,5 cm. Kunststoffteile und Objekte aus kombinierten Kunststoff- und Schaumstoffmaterialien > 0,5 cm werden für die Analyse als Gfrags gruppiert.

# %%
annex_title = Paragraph("Anhang", featuredata.section_title)
frag_sub_title = Paragraph("Schaumstoffe und Kunststoffe nach Grösse", featuredata.subsection_title)

frag_paras = [
    "Die folgende Tabelle enthält die Komponenten «Gfoam» und «Gfrag», die für die Analyse gruppiert wurden. ",
    "Objekte, die als Schaumstoffe gekennzeichnet sind, werden als Gfoam gruppiert und umfassen alle geschäumten ",
    "Polystyrol-Kunststoffe > 0,5 cm. Kunststoffteile und Objekte aus kombinierten Kunststoff - und Schaumstoffmaterialien > 0,5 ",
    "cm werden für die Analyse als Gfrags gruppiert."
]

frag_p = "".join(frag_paras)
frag = Paragraph(frag_p, featuredata.p_style)

frag_caption = [
    f'Fragmentierte und geschäumte Kunststoffe nach Grösse am {this_feature["name"]}',
    f'Median {unit_label}, Anzahl der gefundenen Objekte und Prozent der Gesamtmenge.'
]
frag_captions = ''.join(frag_caption)

# collect the data before aggregating foams for all locations in the survye area
# group by loc_date and code
# Combine the different sizes of fragmented plastics and styrofoam
# the codes for the foams
before_agg = pd.read_csv("resources/checked_before_agg_sdata_eos_2020_21.csv")
some_foams = ["G81", "G82", "G83", "G74"]
before_agg.rename(columns={"p/100m":unit_label}, inplace=True)

# the codes for the fragmented plastics
some_frag_plas = list(before_agg[before_agg.groupname == "plastic pieces"].code.unique())
mask = ((before_agg.code.isin([*some_frag_plas, *some_foams]))&(before_agg.location.isin(admin_summary["locations_of_interest"])))

fd_frags_foams = before_agg[mask].groupby(["loc_date","code"], as_index=False).agg(agg_pcs_quantity)
fd_frags_foams = fd_frags_foams.groupby("code").agg(agg_pcs_median)
fd_frags_foams["item"] = fd_frags_foams.index.map(lambda x: fdx.dMap.loc[x])
fd_frags_foams["% of total"] = (fd_frags_foams.quantity/fd.quantity.sum()).round(2)

# table data
data = fd_frags_foams[["item",unit_label, "quantity", "% of total"]]
data.rename(columns={"item":"Objekt", "quantity":"Objekte (St.)", "% of total":"Anteil"}, inplace=True)
data.set_index("Objekt", inplace=True, drop=True)
data.index.name = None

data.reset_index(inplace=True)

frag_table = featuredata.aStyledTable(data, colWidths=[2.6*inch] + [None]*len(dims_table.columns))
frag_table_caption = Paragraph(frag_captions, featuredata.caption_style)


new_components = [
    featuredata.larger_space,
    code_group_percent,
    featuredata.smallest_space,
    cgpercent_caption,
    featuredata.larger_space,
    code_group_pcsm,
    featuredata.smallest_space,
    cgpcs_caption,
    featuredata.larger_space,
    annex_title,
    featuredata.small_space,
    frag_sub_title,
    featuredata.smaller_space,
    frag,
    featuredata.small_space,
    frag_table,
    featuredata.smallest_space,
    frag_table_caption
]

pdfcomponents = featuredata.addToDoc(new_components, pdfcomponents)


aformatter = {
    f"{unit_label}": lambda x: featuredata.replaceDecimal(x, "de"),
    "Objekte (St.)": lambda x: featuredata.thousandsSeparator(int(x), "de"),
    "Anteil":'{:.0%}',
   
}

frags_table = data.style.format(aformatter).set_table_styles(table_css_styles)


glue("bielersee_frag_table_caption", frag_captions, display=False)
glue("bielersee_frags_table", frags_table, display=False)
# Out:
# 'Fragmentierte und geschäumte Kunststoffe nach Grösse am BielerseeMedian p/100 m, Anzahl der gefundenen Objekte und Prozent der Gesamtmenge.'
# <style type="text/css">
# #T_40815 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_40815 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_40815 tr {
#   font-size: 14px;
# }
# #T_40815 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_40815">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40815_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_40815_level0_col1" class="col_heading level0 col1" >p/100 m</th>
#       <th id="T_40815_level0_col2" class="col_heading level0 col2" >Objekte (St.)</th>
#       <th id="T_40815_level0_col3" class="col_heading level0 col3" >Anteil</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40815_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40815_row0_col0" class="data row0 col0" >Schaumstoffverpackungen/Isolierung</td>
#       <td id="T_40815_row0_col1" class="data row0 col1" >0,0</td>
#       <td id="T_40815_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_40815_row0_col3" class="data row0 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40815_row1_col0" class="data row1 col0" >Objekte aus Kunststoff/Polystyrol 0,5 - 2,5 cm</td>
#       <td id="T_40815_row1_col1" class="data row1 col1" >0,0</td>
#       <td id="T_40815_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_40815_row1_col3" class="data row1 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40815_row2_col0" class="data row2 col0" >Objekte aus Kunststoff/Polystyrol 2,5 - 50 cm</td>
#       <td id="T_40815_row2_col1" class="data row2 col1" >0,0</td>
#       <td id="T_40815_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_40815_row2_col3" class="data row2 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40815_row3_col0" class="data row3 col0" >Objekte aus Kunststoff 0,5 - 2,5 cm</td>
#       <td id="T_40815_row3_col1" class="data row3 col1" >24,0</td>
#       <td id="T_40815_row3_col2" class="data row3 col2" >391</td>
#       <td id="T_40815_row3_col3" class="data row3 col3" >9%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40815_row4_col0" class="data row4 col0" >Objekte aus Kunststoff 2,5 - 50 cm</td>
#       <td id="T_40815_row4_col1" class="data row4 col1" >27,0</td>
#       <td id="T_40815_row4_col2" class="data row4 col2" >342</td>
#       <td id="T_40815_row4_col3" class="data row4 col3" >8%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40815_row5_col0" class="data row5 col0" >Objekte aus Kunststoff > 50 cm</td>
#       <td id="T_40815_row5_col1" class="data row5 col1" >0,0</td>
#       <td id="T_40815_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_40815_row5_col3" class="data row5 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40815_row6_col0" class="data row6 col0" >Objekte aus expandiertem Polystyrol 0,5 - 2,5 cm</td>
#       <td id="T_40815_row6_col1" class="data row6 col1" >0,0</td>
#       <td id="T_40815_row6_col2" class="data row6 col2" >116</td>
#       <td id="T_40815_row6_col3" class="data row6 col3" >3%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40815_row7_col0" class="data row7 col0" >Objekte aus expandiertem Polystyrol 2,5 - 50 cm</td>
#       <td id="T_40815_row7_col1" class="data row7 col1" >2,0</td>
#       <td id="T_40815_row7_col2" class="data row7 col2" >57</td>
#       <td id="T_40815_row7_col3" class="data row7 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_40815_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40815_row8_col0" class="data row8 col0" >Objekte aus expandiertem Polystyrol > 50 cm</td>
#       <td id="T_40815_row8_col1" class="data row8 col1" >0,0</td>
#       <td id="T_40815_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_40815_row8_col3" class="data row8 col3" >0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ```{glue:figure} bielersee_frags_table
# ---
# name: 'bielersee_frags_table'
# ---
# ` `
# ```
# {numref}`Abbildung %s: <bielersee_frags_table>` {glue:text}`bielersee_frag_table_caption`

# %% [markdown]
# ### Die Erhebungsorte

# %%
# display the survey locations
disp_columns = ["latitude", "longitude", "city"]
disp_beaches = admin_details.df_beaches.loc[admin_summary["locations_of_interest"]][disp_columns]
disp_beaches.reset_index(inplace=True)
disp_beaches.rename(columns={"city":"stat", "slug":"standort"}, inplace=True)

# make this into a pdf table
location_subsection = Paragraph("Die Erhebungsorte", featuredata.subsection_title)

pdf_table = featuredata.aStyledTable(disp_beaches)

pdfcomponents = featuredata.addToDoc([featuredata.large_space, location_subsection, featuredata.small_space, pdf_table, ], pdfcomponents)

disp_beaches.set_index("standort", inplace=True, drop=True)

disp_beaches
# Out:
#                                latitude  longitude         stat
# standort
# mullermatte                   47.133339   7.227907  Biel/Bienne
# bielersee_vinelz_fankhausers  47.038398   7.108311       Vinelz
# erlach-camping-strand         47.047159   7.097854       Erlach
# luscherz-plage                47.047955   7.151242     Lüscherz
# strandboden-biel              47.132510   7.233142  Biel/Bienne
# nidau-strand                  47.127196   7.232613        Nidau
# camp-des-peches               47.052812   7.074053  Le Landeron
# ligerz-strand                 47.083979   7.135894       Ligerz
# gals-reserve                  47.046272   7.085007         Gals
# luscherz-two                  47.047519   7.152829     Lüscherz

# %% [markdown]
# ### Inventar der Objekte

# %%
pd.set_option("display.max_rows", None)
complete_inventory = fdx.code_summary.copy()
complete_inventory["quantity"] = complete_inventory["quantity"].map(lambda x: featuredata.thousandsSeparator(x, language))
complete_inventory["% of total"] = complete_inventory["% of total"].astype(int)
complete_inventory[unit_label] = complete_inventory[unit_label].astype(int)
complete_inventory.rename(columns=featuredata.inventory_table_de, inplace=True)

complete_inventory.reset_index(inplace=True)

inventory_subsection = Paragraph("Inventar der Objekte", featuredata.subsection_title)
inventory_table = featuredata.aStyledTable(complete_inventory, colWidths=[1*inch]+[2.2*inch]+[None]*len(complete_inventory.columns))

pdfcomponents = featuredata.addToDoc([featuredata.small_space, inventory_subsection, featuredata.small_space, inventory_table], pdfcomponents)

complete_inventory.set_index("code", inplace=True, drop=True)

complete_inventory.sort_values(by="Objekte (St.)", ascending=False)
# Out:
#                                                   Objekte Objekte (St.)  \
# code
# G940               Schaumstoff EVA (flexibler Kunststoff)            92
# G25               Tabak; Kunststoffverpackungen, Behälter            92
# G942      Kunststoffspäne von Drehbänken, CNC-Bearbeitung             9
# G936                             Folien für Gewächshäuser             9
# G70                                 Schrotflintenpatronen             9
# G4      Kleine Plastikbeutel; Gefrierbeutel, Zippsäckc...             9
# G34                          Besteck, Teller und Tabletts             9
# G148                              Kartonkisten und Stücke             9
# G89                                 Kunststoff-Bauabfälle            89
# G26                                             Feuerzeug             8
# G115                                     Schaumstoff <5mm             8
# G96     Hygienebinden/Höscheneinlagen/Tampons und Appl...             8
# G186                                     Industrieschrott             8
# G117                                       Styropor < 5mm            77
# G904                      Feuerwerkskörper; Raketenkappen            76
# Gfrags                          Fragmentierte Kunststoffe           746
# G27                                      Zigarettenfilter           744
# G74                    Schaumstoffverpackungen/Isolierung            72
# G112                           Industriepellets (Nurdles)            71
# G142                              Seil, Schnur oder Netze             7
# G101    Robidog Hundekot-Säcklein, andere Hundekotsäck...             7
# G118                   Kleine Industrielle Kügelchen <5mm             7
# G122                           Kunststofffragmente (>1mm)             7
# G175                      Getränkedosen (Dosen, Getränke)             7
# G28                  Stifte, Deckel, Druckbleistifte usw.             7
# G95                                  Wattestäbchen/Tupfer            68
# G213                                       Paraffinwachs             65
# G177                      Verpackungen aus Aluminiumfolie            61
# G939                 Kunststoffblumen, Kunststoffpflanzen             6
# G48                                   Seile, synthetische             6
# G7                             Getränkeflaschen < = 0,5 l             6
# G170                                   Holz (verarbeitet)             6
# G59                         Monofile Angelschnur (Angeln)             5
# G901                    Medizinische Masken, synthetische             5
# G208                   Glas oder Keramikfragmente >2.5 cm             5
# G141                                             Teppiche             5
# G156                                      Papierfragmente            49
# G106                       Kunststofffragmente eckig <5mm            46
# G73     Gegenstände aus Schaumstoff & Teilstücke (nich...            40
# G933    Taschen, Etuis für Zubehör, Brillen, Elektroni...             4
# G20                                    Laschen und Deckel             4
# G134                                      Sonstiges Gummi             4
# G49                                           Seile > 1cm             4
# G68                                   Fiberglas-Fragmente             4
# G124                                    Andere Kunststoff             4
# G203    Geschirr aus Keramik oder Glas, Tassen, Teller...             4
# G23                               unidentifizierte Deckel            36
# G31                  Schleckstengel, Stengel von Lutscher            35
# G24                   Ringe von Plastikflaschen/Behältern            35
# G30                                    Snack-Verpackungen           325
# G33                 Einwegartikel; Tassen/Becher & Deckel            32
# G178          Kronkorken, Lasche von Dose/Ausfreisslachen            31
# G35                           Strohhalme und Rührstäbchen            31
# G67                           Industriefolie (Kunststoff)           300
# G917                                              Blähton             3
# G167                        Streichhölzer oder Feuerwerke             3
# G2                                         Säcke, Taschen             3
# G176                   Konservendosen (Lebensmitteldosen)             3
# G38     Abdeckungen; Kunststoffverpackungen, Folien zu...             3
# G64                                             Kotflügel             3
# G931    (Absperr)band für Absperrungen, Polizei, Baust...             3
# G194    Kabel, Metalldraht oft in Gummi- oder Kunststo...             3
# G143                                  Segel und Segeltuch             3
# G119                      Folienartiger Kunststoff (>1mm)             3
# G158                      Sonstige Gegenstände aus Papier             3
# G135    Kleidung, Fussbekleidung, Kopfbedeckung, Hands...             3
# G133                  Kondome einschließlich Verpackungen             3
# G155                Feuerwerkspapierhülsen und -fragmente             3
# G211                     Sonstiges medizinisches Material            29
# G50                                          Schnur < 1cm            25
# G10     Lebensmittelbehälter zum einmaligen Gebrauch a...            24
# G922                               Etiketten, Strichcodes            24
# G22     Deckel für Chemikalien, Reinigungsmittel (Ohne...            21
# G929       Elektronik und Teile; Sensoren, Headsets usw.              2
# G149                                   Papierverpackungen             2
# G201                       Gläser, einschliesslich Stücke             2
# G921                       Keramikfliesen und Bruchstücke             2
# G182       Angeln; Haken, Gewichte, Köder, Senkblei, usw.             2
# G188                       Andere Kanister/Behälter < 4 L             2
# G145                                     Andere Textilien             2
# G12     Kosmetika, Behälter für Körperpflegeprodukte, ...             2
# G930                               Schaumstoff-Ohrstöpsel             2
# G204                  Baumaterial;  Ziegel, Rohre, Zement            19
# G32                            Spielzeug und Partyartikel            19
# G21                   Getränke-Deckel, Getränkeverschluss            18
# G137                      Kleidung, Handtücher und Lappen            18
# G200                         Getränke Glasflasche, Stücke           176
# Gfoam                             Expandiertes Polystyrol           173
# G941            Verpackungsfolien, nicht für Lebensmittel           173
# G908                    Klebeband; elektrisch, isolierend            17
# G152    Papier &Karton;Zigarettenschachteln, Papier/Ka...            16
# G93                                           Kabelbinder            15
# G125                   Luftballons und Luftballonstäbchen            14
# G923    Taschentücher, Toilettenpapier, Servietten, Pa...            14
# G159                                                 Kork            14
# G66     Umreifungsbänder; Hartplastik für Verpackung f...            13
# G98                                Windeln – Feuchttücher            13
# G905    Haarspangen, Haargummis, persönliche Accessoir...            13
# G927    Plastikschnur von Rasentrimmern, die zum Schne...            13
# G191                                     Draht und Gitter            12
# G928                                 Bänder und Schleifen            11
# G198                           Andere Metallteile < 50 cm            11
# G3                       Einkaufstaschen, Shoppingtaschen            11
# G153    Papierbecher, Lebensmittelverpackungen aus Pap...            11
# G100              Medizin; Behälter/Röhrchen/Verpackungen            11
# G87                  Abdeckklebeband/Verpackungsklebeband            10
# G914    Büroklammern, Wäscheklammern, Gebrauchsgegenst...            10
# G91     Bio-Filtermaterial  / Trägermaterial aus Kunst...            10
# G161                                   Verarbeitetes Holz            10
# G165    Glacestengel (Eisstiele), Zahnstocher, Essstäb...            10
# G210                   Sonstiges Glas/Keramik Materialien             1
# G53                           Netze und Teilstücke < 50cm             1
# G43     Sicherheitsetiketten, Siegel für Fischerei ode...             1
# G926                    Kaugummi, enthält oft Kunststoffe             1
# G131                                          Gummibänder             1
# G5                             Plastiksäcke/ Plastiktüten             1
# G104    Kunststofffragmente abgerundet / rundlich  <5m...             1
# G52                                  Netze und Teilstücke             1
# G129                           Schläuche und Gummiplatten             1
# G37                     Netzbeutel, Netztasche, Netzsäcke             1
# G90                               Blumentöpfe aus Plastik             1
# G157                                               Papier             1
# G172                               Sonstiges Holz > 50 cm             1
# G171                                Sonstiges Holz < 50cm             1
# G103                        Kunststofffragmente rund <5mm             1
# G8                                Getränkeflaschen > 0,5L             1
# G41                  Handschuhe Industriell/Professionell             1
# G71                                       Schuhe Sandalen             1
# G938                    Zahnstocher, Zahnseide Kunststoff             1
# G197                                     sonstiges Metall             1
# G913                                            Schnuller             1
# G150                              Milchkartons, Tetrapack             1
# G916                           Bleistifte und Bruchstücke             1
# G918    Sicherheitsnadeln, Büroklammern, kleine Gebrau...             1
# G202                                           Glühbirnen             1
# G36     Säcke aus strapazierfähigem Kunststoff für 25 ...             1
# G102                                           Flip-Flops             0
# G713                                        Skiförderband             0
# G934    Sandsäcke, Kunststoff für Hochwasser- und Eros...             0
# G88                                   Telefon inkl. Teile             0
# G712                                        Skihandschuhe             0
# G84                                      CD oder CD-Hülle             0
# G935    Gummi-Puffer für Geh- und Wanderstöcke und Tei...             0
# G932    Bio-Beads, Mikroplastik für die Abwasserbehand...             0
# G711                                          Handwärmer              0
# G999    Keine Gegenstände bei dieser Erhebung/Studie g...             0
# G94                                             Tischtuch             0
# G99                                     Spritzen - Nadeln             0
# G710    Ski / Snowboards (Ski, Befestigungen und ander...             0
# G944              Pelletmasse aus dem Spritzgussverfahren             0
# G943                     Zäune Landwirtschaft, Kunststoff             0
# G105                  Kunststofffragmente subangulär <5mm             0
# G9      Flaschen und Behälter für Reinigungsmittel und...             0
# G907                         Kaffeekapseln aus Kunststoff             0
# G900       Handschuhe Latex, persönliche Schutzausrüstung             0
# G97                     Behälter von Toilettenerfrischer              0
# G902                           Medizinische Masken, Stoff             0
# G903    Behälter und Packungen für Handdesinfektionsmi...             0
# G945                                        Rasierklingen             0
# G915        Reflektoren, Mobilitätsartikel aus Kunststoff             0
# G919                       Nägel, Schrauben, Bolzen usw.              0
# G92                                         Köderbehälter             0
# G925    Pakete: Trockenmittel/Feuchtigkeitsabsorber, m...             0
# G906                              Kaffeekapseln Aluminium             0
# G937                          Pheromonköder für Weinberge             0
# G114                                          Folien <5mm             0
# G709    Teller von Skistock (runder Teil aus Plastik u...             0
# G708                                            Skistöcke             0
# G185                            Behälter mittlerer Grösse             0
# G183                                 Teile von Angelhaken             0
# G181            Geschirr aus Metall, Tassen, Besteck usw.             0
# G180                                      Haushaltsgeräte             0
# G179                                         Einweg Grill             0
# G174                                    Aerosolspraydosen             0
# G173                                            Sonstiges             0
# G17              Kartuschen von Kartuschen-spritzpistolen             0
# G168                                          Holzbretter             0
# G166                                           Farbpinsel             0
# G162                                               Kisten             0
# G160                                             Paletten             0
# G154                         Zeitungen oder Zeitschriften             0
# G151                                   Tetrapack, Kartons             0
# G111                           Kugelförmige Pellets < 5mm             0
# G147                    Papiertragetaschen, (Papiertüten)             0
# G146                                       Papier, Karton             0
# G144                                              Tampons             0
# G140       Sack oder Beutel (Tragetasche), Jute oder Hanf             0
# G14                Flaschen für Motoröl (Motorölflaschen)             0
# G139                                            Rucksäcke             0
# G138                                  Schuhe und Sandalen             0
# G136                                               Schuhe             0
# G132                                   Schwimmer (Angeln)             0
# G13     Flaschen, Behälter, Fässer zum Transportieren ...             0
# G128                            Reifen und Antriebsriemen             0
# G126                                                Bälle             0
# G123                           Polyurethan-Granulat < 5mm             0
# G116                                        Granulat <5mm             0
# G11            Kosmetika für den Strand, z.B. Sonnencreme             0
# G19                                             Autoteile             0
# G190                Farbtöpfe, Farbbüchsen,  ( Farbeimer)             0
# G55                              Angelschnur (verwickelt)             0
# G707                                Skiausrüstungsetikett             0
# G706                                        Skiabonnement             0
# G705                                 Schrauben und Bolzen             0
# G704                                      Seilbahnbürsten             0
# G703                   Pistenmarkierungspfosten (Plastik)             0
# G702                      Pistenmarkierungspfosten (Holz)             0
# G65                                                 Eimer             0
# G63                                                 Bojen             0
# G62                                   Schwimmer für Netze             0
# G61                                Sonstiges Angelzubehör             0
# G60                    Lichtstab, Knicklicht, Glow-sticks             0
# G6      Flaschen und Behälter aus Kunststoff, nicht fü...             0
# G56                                     Verhedderte Netze             0
# G51                                           Fischernetz             0
# G193                    Teile von Autos und Autobatterien             0
# G40                            Handschuhe Haushalt/Garten             0
# G107                            Zylindrische Pellets <5mm             0
# G39                                            Handschuhe             0
# G108                         Scheibenförmige Pellets <5mm             0
# G113                                           Fäden <5mm             0
# G29                      Kämme, Bürsten und Sonnenbrillen             0
# G109                                  Flache Pellets <5mm             0
# G214                                              Öl/Teer             0
# G207                       Tonkrüge zum Fangen von Kraken             0
# G205                                    Leuchtstoffröhren             0
# G199                           Andere Metallteile > 50 cm             0
# G196                       Grosse metallische Gegenstände             0
# G195                                 Batterien (Haushalt)             0
# G1                                          Sixpack-Ringe             0
#
#         Anteil  p/100 m  Häufigkeitsrate     Material
# code
# G940         2        0               31      Plastik
# G25          2        5               73      Plastik
# G942         0        0               15      Plastik
# G936         0        0               18      Plastik
# G70          0        0               18      Plastik
# G4           0        0               13      Plastik
# G34          0        0               18      Plastik
# G148         0        0               10       Papier
# G89          1        4               71      Plastik
# G26          0        0               18      Plastik
# G115         0        0               15      Plastik
# G96          0        0               15      Plastik
# G186         0        0               13       Metall
# G117         1        0               34      Plastik
# G904         1        4               68      Plastik
# Gfrags      16       53               97      Plastik
# G27         16        9               78      Plastik
# G74          1        1               50      Plastik
# G112         1        2               60      Plastik
# G142         0        0                7        Stoff
# G101         0        0               10      Plastik
# G118         0        0                7      Plastik
# G122         0        0                2      Plastik
# G175         0        0               10       Metall
# G28          0        0               15      Plastik
# G95          1        1               50      Plastik
# G213         1        0               26  Chemikalien
# G177         1        2               60       Metall
# G939         0        0               10      Plastik
# G48          0        0               15      Plastik
# G7           0        0               10      Plastik
# G170         0        0                7         Holz
# G59          0        0               10      Plastik
# G901         0        0               10      Plastik
# G208         0        0                7         Glas
# G141         0        0                7        Stoff
# G156         1        0               31       Papier
# G106         1        0               47      Plastik
# G73          0        0               31      Plastik
# G933         0        0                7      Plastik
# G20          0        0               10      Plastik
# G134         0        0                5        Gummi
# G49          0        0                5      Plastik
# G68          0        0               10      Plastik
# G124         0        0                5      Plastik
# G203         0        0                7         Glas
# G23          0        0               42      Plastik
# G31          0        0               39      Plastik
# G24          0        0               44      Plastik
# G30          7       21               86      Plastik
# G33          0        0               42      Plastik
# G178         0        0               47       Metall
# G35          0        0               44      Plastik
# G67          6       18               89      Plastik
# G917         0        0                5         Glas
# G167         0        0                2         Holz
# G2           0        0                2      Plastik
# G176         0        0                5       Metall
# G38          0        0                7      Plastik
# G64          0        0                2      Plastik
# G931         0        0                2      Plastik
# G194         0        0                7       Metall
# G143         0        0                7        Stoff
# G119         0        0                2      Plastik
# G158         0        0                5       Papier
# G135         0        0                7        Stoff
# G133         0        0                7        Gummi
# G155         0        0                7       Papier
# G211         0        1               50      Plastik
# G50          0        0               34      Plastik
# G10          0        0               42      Plastik
# G922         0        0               31      Plastik
# G22          0        0               34      Plastik
# G929         0        0                5       Metall
# G149         0        0                5       Papier
# G201         0        0                2         Glas
# G921         0        0                5         Glas
# G182         0        0                2       Metall
# G188         0        0                2       Metall
# G145         0        0                5        Stoff
# G12          0        0                5      Plastik
# G930         0        0                5      Plastik
# G204         0        0                2         Glas
# G32          0        0               39      Plastik
# G21          0        0               28      Plastik
# G137         0        0               21        Stoff
# G200         3        5               68         Glas
# Gfoam        3        5               63      Plastik
# G941         3        9               63      Plastik
# G908         0        0               34      Plastik
# G152         0        0               13       Papier
# G93          0        0               26      Plastik
# G125         0        0               21        Gummi
# G923         0        0               18       Papier
# G159         0        0               18         Holz
# G66          0        0               23      Plastik
# G98          0        0               23      Plastik
# G905         0        0               26      Plastik
# G927         0        0               13      Plastik
# G191         0        0               23       Metall
# G928         0        0               23      Plastik
# G198         0        0               23       Metall
# G3           0        0               15      Plastik
# G153         0        0               18       Papier
# G100         0        0               26      Plastik
# G87          0        0               23      Plastik
# G914         0        0               10      Plastik
# G91          0        0               21      Plastik
# G161         0        0               10         Holz
# G165         0        0               18         Holz
# G210         0        0                2         Glas
# G53          0        0                2      Plastik
# G43          0        0                2      Plastik
# G926         0        0                2      Plastik
# G131         0        0                2        Gummi
# G5           0        0                2      Plastik
# G104         0        0                2      Plastik
# G52          0        0                2      Plastik
# G129         0        0                2        Gummi
# G37          0        0                2      Plastik
# G90          0        0                2      Plastik
# G157         0        0                2       Papier
# G172         0        0                2         Holz
# G171         0        0                2         Holz
# G103         0        0                2      Plastik
# G8           0        0                2      Plastik
# G41          0        0                2      Plastik
# G71          0        0                2      Plastik
# G938         0        0                2      Plastik
# G197         0        0                2       Metall
# G913         0        0                2      Plastik
# G150         0        0                2       Papier
# G916         0        0                2         Holz
# G918         0        0                2       Metall
# G202         0        0                2         Glas
# G36          0        0                2      Plastik
# G102         0        0                0      Plastik
# G713         0        0                0      Plastik
# G934         0        0                0      Plastik
# G88          0        0                0      Plastik
# G712         0        0                0        Stoff
# G84          0        0                0      Plastik
# G935         0        0                0      Plastik
# G932         0        0                0      Plastik
# G711         0        0                0      Plastik
# G999         0        0                0    Unbekannt
# G94          0        0                0      Plastik
# G99          0        0                0      Plastik
# G710         0        0                0      Plastik
# G944         0        0                0      Plastik
# G943         0        0                0      Plastik
# G105         0        0                0      Plastik
# G9           0        0                0      Plastik
# G907         0        0                0      Plastik
# G900         0        0                0        Gummi
# G97          0        0                0      Plastik
# G902         0        0                0        Stoff
# G903         0        0                0      Plastik
# G945         0        0                0       Metall
# G915         0        0                0      Plastik
# G919         0        0                0       Metall
# G92          0        0                0      Plastik
# G925         0        0                0      Plastik
# G906         0        0                0       Metall
# G937         0        0                0      Plastik
# G114         0        0                0      Plastik
# G709         0        0                0      Plastik
# G708         0        0                0       Metall
# G185         0        0                0       Metall
# G183         0        0                0       Metall
# G181         0        0                0       Metall
# G180         0        0                0       Metall
# G179         0        0                0       Metall
# G174         0        0                0       Metall
# G173         0        0                0         Holz
# G17          0        0                0      Plastik
# G168         0        0                0         Holz
# G166         0        0                0         Holz
# G162         0        0                0         Holz
# G160         0        0                0         Holz
# G154         0        0                0       Papier
# G151         0        0                0       Papier
# G111         0        0                0      Plastik
# G147         0        0                0       Papier
# G146         0        0                0       Papier
# G144         0        0                0        Stoff
# G140         0        0                0        Stoff
# G14          0        0                0      Plastik
# G139         0        0                0        Stoff
# G138         0        0                0        Stoff
# G136         0        0                0        Stoff
# G132         0        0                0        Gummi
# G13          0        0                0      Plastik
# G128         0        0                0        Gummi
# G126         0        0                0        Gummi
# G123         0        0                0      Plastik
# G116         0        0                0      Plastik
# G11          0        0                0      Plastik
# G19          0        0                0      Plastik
# G190         0        0                0       Metall
# G55          0        0                0      Plastik
# G707         0        0                0      Plastik
# G706         0        0                0      Plastik
# G705         0        0                0       Metall
# G704         0        0                0      Plastik
# G703         0        0                0      Plastik
# G702         0        0                0         Holz
# G65          0        0                0      Plastik
# G63          0        0                0      Plastik
# G62          0        0                0      Plastik
# G61          0        0                0      Plastik
# G60          0        0                0      Plastik
# G6           0        0                0      Plastik
# G56          0        0                0      Plastik
# G51          0        0                0      Plastik
# G193         0        0                0       Metall
# G40          0        0                0      Plastik
# G107         0        0                0      Plastik
# G39          0        0                0      Plastik
# G108         0        0                0      Plastik
# G113         0        0                0      Plastik
# G29          0        0                0      Plastik
# G109         0        0                0      Plastik
# G214         0        0                0  Chemikalien
# G207         0        0                0         Glas
# G205         0        0                0         Glas
# G199         0        0                0       Metall
# G196         0        0                0       Metall
# G195         0        0                0       Metall
# G1           0        0                0      Plastik

# %%
# pdfcomponents = featuredata.addToDoc([featuredata.large_space, pdf_table], pdfcomponents)

doc = SimpleDocTemplate("bielersee.pdf", pagesize=A4, leftMargin=.5*inch, rightMargin=.5*inch, topMargin=.5*inch, bottomMargin=.5*inch)
pageinfo= f"IQAASL: {this_feature['name']} {start_date} bis {end_date}"

def myLaterPages(canvas, doc):
    canvas.saveState()
    canvas.setFont('Times-Italic',9)
    canvas.drawString(.5*inch, 0.25* inch, "S.%d %s" % (doc.page, pageinfo))
    canvas.restoreState()
    
doc.build(pdfcomponents,  onFirstPage=myLaterPages, onLaterPages=myLaterPages)
